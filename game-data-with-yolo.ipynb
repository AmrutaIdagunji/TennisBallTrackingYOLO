# %%
import os
import pandas as pd
import numpy as np
import cv2
import shutil

# %%
def process_heatmap(heatmap_path, threshold=128):
    # Load the heatmap
    heatmap = cv2.imread(heatmap_path, cv2.IMREAD_GRAYSCALE)

    # Threshold the heatmap to find the "hot" areas
    _, binary_heatmap = cv2.threshold(heatmap, threshold, 255, cv2.THRESH_BINARY)

    # Find contours in the binary heatmap
    contours, _ = cv2.findContours(binary_heatmap, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if contours:
        # Assuming the largest contour corresponds to the ball
        largest_contour = max(contours, key=cv2.contourArea)
        x, y, w, h = cv2.boundingRect(largest_contour)

        # Convert bounding box coordinates to YOLO format
        img_height, img_width = heatmap.shape
        x_center = (x + w / 2) / img_width
        y_center = (y + h / 2) / img_height
        width = w / img_width
        height = h / img_height

        return [0, x_center, y_center, width, height]  # Class ID is assumed to be 0

# %%
def create_yolo_annotations(heatmaps_folder):
    for filename in os.listdir(heatmaps_folder):        
        if filename.endswith("_heatmap.jpg"):
            heatmap_path = os.path.abspath(os.path.join(heatmaps_folder, filename))
            bbox = process_heatmap(heatmap_path)

            if bbox:
                # Prepare YOLO annotation line
                yolo_format = ' '.join(map(str, bbox))

                # Write the annotation to a file
                annotation_filename = filename.replace('_heatmap.jpg', '.txt')
                annot_folder = "/".join(heatmaps_folder.split("/")[:-1])
                with open(os.path.join(annot_folder, annotation_filename), 'w') as file:
                    file.write(yolo_format + '\n')

# %%
def create_heatmap(x, y, width, height, sigma=25):
    xs = np.linspace(0, width, width)
    ys = np.linspace(0, height, height)
    xs, ys = np.meshgrid(xs, ys)

    # Create a Gaussian centered at (x, y)
    heatmap = np.exp(-((xs - x)**2 + (ys - y)**2) / (2 * sigma**2))

    return heatmap

# %%
def save_heatmaps_for_clip(clip_path, output_path, image_shape, x, y):
    game, clip, clip_name = clip_path.split("/")[-3:]
    heatmap_filename = game + "_" + clip + "_" + clip_name.split(".")[0] + '_heatmap.jpg'
    
    image_path = os.path.join("/".join(output_path.split("/")[:-1]), game + "_" + clip + "_" + clip_name)
    
    if not os.path.exists(os.path.join(output_path, heatmap_filename)):
        heatmap = create_heatmap(x, y, image_shape[1], image_shape[0])

        # Normalize, convert to uint8, and save the heatmap
        heatmap_normalized = cv2.normalize(heatmap, None, 0, 255, cv2.NORM_MINMAX)
        heatmap_normalized = np.uint8(heatmap_normalized)
        
        shutil.copy(clip_path, image_path)
        cv2.imwrite(os.path.join(output_path, heatmap_filename), heatmap_normalized)

# %%
base_dataset_path = "/kaggle/input/gamedataset/Dataset"
base_path = "/kaggle/working/"

os.makedirs("/kaggle/working/train/heatmaps", exist_ok=True)
os.makedirs("/kaggle/working/test/heatmaps", exist_ok=True)
os.makedirs("/kaggle/working/val/heatmaps", exist_ok=True)

heatmaps = []
status = []
image_shape = (720, 1280)  # Assuming 720p resolution for the heatmaps
count = 0
for i, game_folder in enumerate(os.listdir(base_dataset_path)):
    game_path = os.path.join(base_dataset_path, game_folder)
    
    if(game_folder not in ("Readme.docx", ".DS_Store")):
        count += 1
        for clip_folder in os.listdir(game_path):
            if(clip_folder !=  ".DS_Store"):
                clip_path = os.path.join(game_path, clip_folder)
                labels = pd.read_csv(os.path.join(clip_path, 'Label.csv'))

                for _, row in labels.iterrows():
                    x, y = row['x-coordinate'], row['y-coordinate']

                    if row['visibility'] > 0:
                        image_path = os.path.join(clip_path, row['file name'])
                        if (count < 3):
                            destination_folder = os.path.join(base_path, "train", "heatmaps")
                        elif (count >= 3 and count < 4):
                            destination_folder = os.path.join(base_path, "val", "heatmaps")
                        elif (count >= 4 and count < 5):
                            destination_folder = os.path.join(base_path, "test", "heatmaps")
                        else:
                            break
                        save_heatmaps_for_clip(image_path, destination_folder, image_shape, x, y)

# %%
shutil.rmtree('/kaggle/working/train')
shutil.rmtree('/kaggle/working/test')
shutil.rmtree('/kaggle/working/val')

# %%
# %cd /kaggle/working
from IPython.display import FileLinks

#!zip -r file.zip /kaggle/working
FileLink(r'file.zip')
# Out:
# /kaggle/working
# /kaggle/working/file.zip

# %%
import warnings

warnings.filterwarnings("ignore")

create_yolo_annotations("/kaggle/working/train/heatmaps")
create_yolo_annotations("/kaggle/working/test/heatmaps")
create_yolo_annotations("/kaggle/working/val/heatmaps")

warnings.filterwarnings("default")

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16094, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 16094 (delta 0), reused 4 (delta 0), pack-reused 16089
# Receiving objects: 100% (16094/16094), 14.82 MiB | 22.55 MiB/s, done.
# Resolving deltas: 100% (11023/11023), done.

# %%
# %cd /kaggle/working/yolov5
# !pwd  # Should display /content/yolov5
# Out:
# /kaggle/working/yolov5
# /kaggle/working/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.1.32)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.7.4)
# Requirement already satisfied: numpy>=1.22.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (4.8.1.78)
# Requirement already satisfied: Pillow>=10.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (10.1.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (5.9.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (1.11.4)
# Requirement already satisfied: thop>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.15.1)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (4.66.1)
# Requirement already satisfied: ultralytics>=8.0.147 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (8.0.227)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (68.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2023.11.17)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.0.147->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)

# %%
# !pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (6.0.1)

# %%
import yaml

# Your data to be written to the YAML file
data = {
    'train': '/kaggle/working/train',
    'val': '/kaggle/working/val',
    'nc': 1,
    'names': ['ball']
}

# Specify the path for the YAML file
yaml_file_path = '/kaggle/working/dataset.yaml'

# Write data to the YAML file
with open(yaml_file_path, 'w') as yaml_file:
    yaml.dump(data, yaml_file, default_flow_style=False)

print(f"YAML file '{yaml_file_path}' created successfully.")
# Out:
# YAML file '/kaggle/working/dataset.yaml' created successfully.

# %%
import os
import shutil

def copy_txt_files(source_folder, destination_folder):
    for filename in os.listdir(source_folder):
        if filename.endswith(".txt"):
            source_path = os.path.join(source_folder, filename)
            destination_path = os.path.join(destination_folder, filename)
            shutil.copy(source_path, destination_path)

source_folder = "/kaggle/working/train/heatmaps"
destination_folder = "/kaggle/working/train"
copy_txt_files(source_folder, destination_folder)

source_folder = "/kaggle/working/test/heatmaps"
destination_folder = "/kaggle/working/test"
copy_txt_files(source_folder, destination_folder)

source_folder = "/kaggle/working/val/heatmaps"
destination_folder = "/kaggle/working/val"
copy_txt_files(source_folder, destination_folder)

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data '/kaggle/working/dataset.yaml' --weights yolov5s.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5s.pt, cfg=, data=/kaggle/working/dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: Ultralytics requirement ['Pillow>=10.0.1'] not found, attempting AutoUpdate...
# Requirement already satisfied: Pillow>=10.0.1 in /opt/conda/lib/python3.10/site-packages (10.1.0)
#
# requirements: AutoUpdate success ✅ 11.0s, installed 1 package: ['Pillow>=10.0.1']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 13.7MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|███████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 122MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# WARNING ⚠️ DP not recommended, use torch.distributed.run for best DDP Multi-GPU results.
# See Multi-GPU Tutorial at https://docs.ultralytics.com/yolov5/tutorials/multi_gpu_training to get started.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /kaggle/working/train... 3863 images, 3863 backgrounds, 0 corrup
# train: New cache created: /kaggle/working/train.cache
# train: Caching images (5.0GB ram): 100%|██████████| 7726/7726 [00:27<00:00, 281.
# val: Scanning /kaggle/working/val... 1920 images, 1920 backgrounds, 0 corrupt: 1
# val: New cache created: /kaggle/working/val.cache
# val: Caching images (2.5GB ram): 100%|██████████| 3840/3840 [00:12<00:00, 298.46
#
# AutoAnchor: 5.87 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/49      1.83G    0.08818    0.01358          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920     0.0396      0.225     0.0354     0.0162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/49      2.03G    0.05377   0.009322          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.575      0.231      0.273      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/49      2.03G    0.05136   0.007893          0         19        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920    0.00963     0.0365     0.0106    0.00434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/49      2.03G    0.05059   0.007367          0         15        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.161     0.0469     0.0392     0.0267
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/49      2.03G    0.04645   0.006891          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.216      0.271      0.134     0.0764
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/49      2.03G    0.04163    0.00651          0         14        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.488       0.19      0.204      0.146
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/49      2.03G    0.03865   0.006153          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.581      0.295      0.341      0.218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/49      2.03G    0.03652    0.00583          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920     0.0833      0.103     0.0465     0.0246
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/49      2.03G    0.03358   0.005484          0         14        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.065      0.183      0.042      0.026
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/49      2.03G    0.03289   0.005372          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.617       0.22      0.274      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/49      2.03G    0.03238   0.005347          0         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.544       0.17      0.197     0.0841
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/49      2.03G     0.0318   0.005142          0         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.244      0.189      0.154     0.0633
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/49      2.03G    0.03013   0.004966          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.183      0.227       0.16     0.0588
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/49      2.03G    0.02882   0.004598          0         14        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.119      0.141     0.0592     0.0218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/49      2.03G    0.02835   0.004586          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.442      0.274      0.309      0.184
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/49      2.03G      0.028   0.004539          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.388      0.115      0.112     0.0306
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/49      2.03G    0.02807   0.004513          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920     0.0532     0.0599     0.0161    0.00614
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/49      2.03G    0.02712   0.004353          0         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.412      0.104      0.119      0.023
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/49      2.03G    0.02699   0.004235          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.288      0.177      0.149     0.0827
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/49      2.03G    0.02582   0.004052          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.281       0.21      0.188     0.0799
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/49      2.03G    0.02477   0.003923          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.619      0.289      0.347      0.209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/49      2.03G    0.02496    0.00397          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.302      0.266       0.24       0.11
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/49      2.03G    0.02549   0.003923          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.365      0.224      0.217      0.144
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/49      2.03G    0.02448   0.003854          0         14        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.515      0.261      0.291      0.199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/49      2.03G    0.02426   0.003851          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.646      0.268       0.31      0.204
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/49      2.03G    0.02332   0.003691          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.571      0.264      0.305      0.196
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/49      2.03G    0.02319   0.003611          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.428      0.209      0.201     0.0965
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/49      2.03G    0.02293   0.003671          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.519      0.258      0.262      0.173
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/49      2.03G    0.02292   0.003624          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.643        0.3      0.364        0.2
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/49      2.03G     0.0222   0.003423          0         18        640: 1
#       30/49      2.03G    0.02214   0.003436          0         16        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.532       0.29      0.327      0.231
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/49      2.03G     0.0215   0.003383          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.631      0.346      0.386      0.277
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/49      2.03G    0.02144   0.003347          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.661      0.353      0.439       0.31
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/49      2.03G    0.02079   0.003329          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.735      0.339      0.428      0.283
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/49      2.03G    0.02087   0.003352          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.503      0.286      0.308      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/49      2.03G    0.02066   0.003255          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.702      0.423      0.504      0.341
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/49      2.03G    0.02058   0.003228          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.573      0.452      0.482      0.316
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/49      2.03G    0.02017   0.003204          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.661      0.396      0.446      0.313
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/49      2.03G    0.01972   0.003122          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.686      0.454      0.505      0.353
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/49      2.03G    0.01935   0.003097          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.697      0.398      0.474      0.334
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/49      2.03G    0.01868   0.002984          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.684      0.382      0.443       0.31
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/49      2.03G    0.01844   0.002939          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.694      0.418      0.474       0.28
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/49      2.03G    0.01873   0.003033          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.666      0.449      0.505       0.33
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/49      2.03G    0.01888   0.003053          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.664      0.413      0.466      0.301
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/49      2.03G    0.01821   0.002944          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.585      0.386       0.41      0.258
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/49      2.03G    0.01794    0.00286          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.725      0.381      0.463        0.3
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/49      2.03G    0.01792   0.002958          0         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.633      0.373      0.435       0.28
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/49      2.03G    0.01719   0.002812          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.668      0.412      0.483      0.346
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/49      2.03G    0.01707   0.002807          0         14        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920       0.67      0.439      0.506      0.354
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/49      2.03G     0.0168   0.002764          0         16        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.682      0.444      0.505      0.334
#
# 50 epochs completed in 1.355 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.3MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all       3840       1920      0.672      0.439      0.506      0.354
# Results saved to runs/train/exp

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /kaggle/working/test/

#game2_Clip5_0129.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/kaggle/working/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: Ultralytics requirement ['Pillow>=10.0.1'] not found, attempting AutoUpdate...
# Requirement already satisfied: Pillow>=10.0.1 in /opt/conda/lib/python3.10/site-packages (10.1.0)
#
# requirements: AutoUpdate success ✅ 11.0s, installed 1 package: ['Pillow>=10.0.1']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2219 /kaggle/working/test/game2_Clip1_0000.jpg: 384x640 (no detections), 54.6ms
# image 2/2219 /kaggle/working/test/game2_Clip1_0001.jpg: 384x640 (no detections), 7.5ms
# image 3/2219 /kaggle/working/test/game2_Clip1_0002.jpg: 384x640 (no detections), 7.5ms
# image 4/2219 /kaggle/working/test/game2_Clip1_0003.jpg: 384x640 (no detections), 7.5ms
# image 5/2219 /kaggle/working/test/game2_Clip1_0004.jpg: 384x640 (no detections), 7.5ms
# image 6/2219 /kaggle/working/test/game2_Clip1_0005.jpg: 384x640 1 ball, 7.5ms
# image 7/2219 /kaggle/working/test/game2_Clip1_0006.jpg: 384x640 (no detections), 7.5ms
# image 8/2219 /kaggle/working/test/game2_Clip1_0007.jpg: 384x640 (no detections), 7.5ms
# image 9/2219 /kaggle/working/test/game2_Clip1_0008.jpg: 384x640 1 ball, 7.5ms
# image 10/2219 /kaggle/working/test/game2_Clip1_0009.jpg: 384x640 2 balls, 7.5ms
# image 11/2219 /kaggle/working/test/game2_Clip1_0010.jpg: 384x640 1 ball, 7.5ms
# image 12/2219 /kaggle/working/test/game2_Clip1_0011.jpg: 384x640 1 ball, 7.5ms
# image 13/2219 /kaggle/working/test/game2_Clip1_0012.jpg: 384x640 1 ball, 7.5ms
# image 14/2219 /kaggle/working/test/game2_Clip1_0013.jpg: 384x640 1 ball, 7.5ms
# image 15/2219 /kaggle/working/test/game2_Clip1_0014.jpg: 384x640 1 ball, 7.5ms
# image 16/2219 /kaggle/working/test/game2_Clip1_0015.jpg: 384x640 1 ball, 7.5ms
# image 17/2219 /kaggle/working/test/game2_Clip1_0016.jpg: 384x640 1 ball, 7.5ms
# image 18/2219 /kaggle/working/test/game2_Clip1_0017.jpg: 384x640 1 ball, 7.5ms
# image 19/2219 /kaggle/working/test/game2_Clip1_0018.jpg: 384x640 2 balls, 7.5ms
# image 20/2219 /kaggle/working/test/game2_Clip1_0019.jpg: 384x640 1 ball, 7.5ms
# image 21/2219 /kaggle/working/test/game2_Clip1_0020.jpg: 384x640 1 ball, 7.5ms
# image 22/2219 /kaggle/working/test/game2_Clip1_0021.jpg: 384x640 (no detections), 7.5ms
# image 23/2219 /kaggle/working/test/game2_Clip1_0022.jpg: 384x640 1 ball, 7.5ms
# image 24/2219 /kaggle/working/test/game2_Clip1_0023.jpg: 384x640 (no detections), 7.5ms
# image 25/2219 /kaggle/working/test/game2_Clip1_0024.jpg: 384x640 1 ball, 7.5ms
# image 26/2219 /kaggle/working/test/game2_Clip1_0025.jpg: 384x640 (no detections), 7.5ms
# image 27/2219 /kaggle/working/test/game2_Clip1_0026.jpg: 384x640 1 ball, 7.5ms
# image 28/2219 /kaggle/working/test/game2_Clip1_0027.jpg: 384x640 1 ball, 7.5ms
# image 29/2219 /kaggle/working/test/game2_Clip1_0028.jpg: 384x640 1 ball, 7.5ms
# image 30/2219 /kaggle/working/test/game2_Clip1_0029.jpg: 384x640 1 ball, 7.5ms
# image 31/2219 /kaggle/working/test/game2_Clip1_0030.jpg: 384x640 1 ball, 7.5ms
# image 32/2219 /kaggle/working/test/game2_Clip1_0031.jpg: 384x640 1 ball, 7.5ms
# image 33/2219 /kaggle/working/test/game2_Clip1_0032.jpg: 384x640 1 ball, 7.5ms
# image 34/2219 /kaggle/working/test/game2_Clip1_0033.jpg: 384x640 1 ball, 7.5ms
# image 35/2219 /kaggle/working/test/game2_Clip1_0034.jpg: 384x640 1 ball, 7.5ms
# image 36/2219 /kaggle/working/test/game2_Clip1_0035.jpg: 384x640 1 ball, 7.5ms
# image 37/2219 /kaggle/working/test/game2_Clip1_0036.jpg: 384x640 1 ball, 7.5ms
# image 38/2219 /kaggle/working/test/game2_Clip1_0037.jpg: 384x640 (no detections), 7.5ms
# image 39/2219 /kaggle/working/test/game2_Clip1_0038.jpg: 384x640 (no detections), 7.5ms
# image 40/2219 /kaggle/working/test/game2_Clip1_0039.jpg: 384x640 (no detections), 7.5ms
# image 41/2219 /kaggle/working/test/game2_Clip1_0040.jpg: 384x640 (no detections), 7.5ms
# image 42/2219 /kaggle/working/test/game2_Clip1_0041.jpg: 384x640 (no detections), 7.5ms
# image 43/2219 /kaggle/working/test/game2_Clip1_0042.jpg: 384x640 (no detections), 7.5ms
# image 44/2219 /kaggle/working/test/game2_Clip1_0043.jpg: 384x640 (no detections), 7.5ms
# image 45/2219 /kaggle/working/test/game2_Clip1_0044.jpg: 384x640 (no detections), 7.5ms
# image 46/2219 /kaggle/working/test/game2_Clip1_0045.jpg: 384x640 1 ball, 7.5ms
# image 47/2219 /kaggle/working/test/game2_Clip1_0046.jpg: 384x640 (no detections), 7.5ms
# image 48/2219 /kaggle/working/test/game2_Clip1_0047.jpg: 384x640 1 ball, 7.5ms
# image 49/2219 /kaggle/working/test/game2_Clip1_0048.jpg: 384x640 (no detections), 7.5ms
# image 50/2219 /kaggle/working/test/game2_Clip1_0049.jpg: 384x640 1 ball, 8.9ms
# image 51/2219 /kaggle/working/test/game2_Clip1_0050.jpg: 384x640 1 ball, 7.5ms
# image 52/2219 /kaggle/working/test/game2_Clip1_0051.jpg: 384x640 (no detections), 7.5ms
# image 53/2219 /kaggle/working/test/game2_Clip1_0052.jpg: 384x640 2 balls, 7.5ms
# image 54/2219 /kaggle/working/test/game2_Clip1_0053.jpg: 384x640 1 ball, 7.5ms
# image 55/2219 /kaggle/working/test/game2_Clip1_0054.jpg: 384x640 1 ball, 7.5ms
# image 56/2219 /kaggle/working/test/game2_Clip1_0055.jpg: 384x640 1 ball, 7.5ms
# image 57/2219 /kaggle/working/test/game2_Clip1_0056.jpg: 384x640 1 ball, 7.5ms
# image 58/2219 /kaggle/working/test/game2_Clip1_0057.jpg: 384x640 1 ball, 7.5ms
# image 59/2219 /kaggle/working/test/game2_Clip1_0058.jpg: 384x640 1 ball, 7.5ms
# image 60/2219 /kaggle/working/test/game2_Clip1_0059.jpg: 384x640 1 ball, 7.5ms
# image 61/2219 /kaggle/working/test/game2_Clip1_0060.jpg: 384x640 1 ball, 7.5ms
# image 62/2219 /kaggle/working/test/game2_Clip1_0061.jpg: 384x640 1 ball, 7.5ms
# image 63/2219 /kaggle/working/test/game2_Clip1_0062.jpg: 384x640 1 ball, 7.5ms
# image 64/2219 /kaggle/working/test/game2_Clip1_0063.jpg: 384x640 1 ball, 7.5ms
# image 65/2219 /kaggle/working/test/game2_Clip1_0064.jpg: 384x640 1 ball, 7.5ms
# image 66/2219 /kaggle/working/test/game2_Clip1_0065.jpg: 384x640 1 ball, 7.5ms
# image 67/2219 /kaggle/working/test/game2_Clip1_0066.jpg: 384x640 1 ball, 7.5ms
# image 68/2219 /kaggle/working/test/game2_Clip1_0067.jpg: 384x640 1 ball, 7.5ms
# image 69/2219 /kaggle/working/test/game2_Clip1_0068.jpg: 384x640 1 ball, 7.5ms
# image 70/2219 /kaggle/working/test/game2_Clip1_0069.jpg: 384x640 1 ball, 7.5ms
# image 71/2219 /kaggle/working/test/game2_Clip1_0070.jpg: 384x640 1 ball, 7.5ms
# image 72/2219 /kaggle/working/test/game2_Clip1_0071.jpg: 384x640 1 ball, 7.5ms
# image 73/2219 /kaggle/working/test/game2_Clip1_0072.jpg: 384x640 1 ball, 7.5ms
# image 74/2219 /kaggle/working/test/game2_Clip1_0073.jpg: 384x640 1 ball, 7.5ms
# image 75/2219 /kaggle/working/test/game2_Clip1_0074.jpg: 384x640 1 ball, 7.5ms
# image 76/2219 /kaggle/working/test/game2_Clip1_0075.jpg: 384x640 1 ball, 7.4ms
# image 77/2219 /kaggle/working/test/game2_Clip1_0076.jpg: 384x640 1 ball, 7.5ms
# image 78/2219 /kaggle/working/test/game2_Clip1_0077.jpg: 384x640 1 ball, 7.5ms
# image 79/2219 /kaggle/working/test/game2_Clip1_0078.jpg: 384x640 1 ball, 7.5ms
# image 80/2219 /kaggle/working/test/game2_Clip1_0079.jpg: 384x640 1 ball, 7.5ms
# image 81/2219 /kaggle/working/test/game2_Clip1_0080.jpg: 384x640 1 ball, 7.5ms
# image 82/2219 /kaggle/working/test/game2_Clip1_0081.jpg: 384x640 1 ball, 7.5ms
# image 83/2219 /kaggle/working/test/game2_Clip1_0082.jpg: 384x640 1 ball, 7.5ms
# image 84/2219 /kaggle/working/test/game2_Clip1_0083.jpg: 384x640 1 ball, 7.5ms
# image 85/2219 /kaggle/working/test/game2_Clip1_0084.jpg: 384x640 1 ball, 7.5ms
# image 86/2219 /kaggle/working/test/game2_Clip1_0085.jpg: 384x640 1 ball, 7.5ms
# image 87/2219 /kaggle/working/test/game2_Clip1_0086.jpg: 384x640 1 ball, 7.4ms
# image 88/2219 /kaggle/working/test/game2_Clip1_0087.jpg: 384x640 1 ball, 7.5ms
# image 89/2219 /kaggle/working/test/game2_Clip1_0088.jpg: 384x640 1 ball, 7.5ms
# image 90/2219 /kaggle/working/test/game2_Clip1_0089.jpg: 384x640 1 ball, 7.5ms
# image 91/2219 /kaggle/working/test/game2_Clip1_0090.jpg: 384x640 1 ball, 7.5ms
# image 92/2219 /kaggle/working/test/game2_Clip1_0091.jpg: 384x640 1 ball, 7.5ms
# image 93/2219 /kaggle/working/test/game2_Clip1_0092.jpg: 384x640 1 ball, 7.4ms
# image 94/2219 /kaggle/working/test/game2_Clip1_0093.jpg: 384x640 1 ball, 7.5ms
# image 95/2219 /kaggle/working/test/game2_Clip1_0094.jpg: 384x640 1 ball, 7.5ms
# image 96/2219 /kaggle/working/test/game2_Clip1_0095.jpg: 384x640 1 ball, 7.5ms
# image 97/2219 /kaggle/working/test/game2_Clip1_0096.jpg: 384x640 1 ball, 7.5ms
# image 98/2219 /kaggle/working/test/game2_Clip1_0097.jpg: 384x640 1 ball, 7.5ms
# image 99/2219 /kaggle/working/test/game2_Clip1_0098.jpg: 384x640 (no detections), 7.5ms
# image 100/2219 /kaggle/working/test/game2_Clip1_0099.jpg: 384x640 1 ball, 7.5ms
# image 101/2219 /kaggle/working/test/game2_Clip1_0100.jpg: 384x640 1 ball, 7.5ms
# image 102/2219 /kaggle/working/test/game2_Clip1_0101.jpg: 384x640 1 ball, 7.5ms
# image 103/2219 /kaggle/working/test/game2_Clip1_0102.jpg: 384x640 1 ball, 7.5ms
# image 104/2219 /kaggle/working/test/game2_Clip1_0103.jpg: 384x640 1 ball, 7.5ms
# image 105/2219 /kaggle/working/test/game2_Clip1_0104.jpg: 384x640 1 ball, 7.5ms
# image 106/2219 /kaggle/working/test/game2_Clip1_0105.jpg: 384x640 1 ball, 7.5ms
# image 107/2219 /kaggle/working/test/game2_Clip1_0106.jpg: 384x640 1 ball, 7.5ms
# image 108/2219 /kaggle/working/test/game2_Clip1_0107.jpg: 384x640 1 ball, 7.5ms
# image 109/2219 /kaggle/working/test/game2_Clip1_0108.jpg: 384x640 1 ball, 7.5ms
# image 110/2219 /kaggle/working/test/game2_Clip1_0109.jpg: 384x640 1 ball, 7.5ms
# image 111/2219 /kaggle/working/test/game2_Clip1_0110.jpg: 384x640 1 ball, 7.5ms
# image 112/2219 /kaggle/working/test/game2_Clip1_0111.jpg: 384x640 1 ball, 7.5ms
# image 113/2219 /kaggle/working/test/game2_Clip1_0112.jpg: 384x640 1 ball, 7.5ms
# image 114/2219 /kaggle/working/test/game2_Clip1_0113.jpg: 384x640 1 ball, 7.5ms
# image 115/2219 /kaggle/working/test/game2_Clip1_0114.jpg: 384x640 1 ball, 7.5ms
# image 116/2219 /kaggle/working/test/game2_Clip1_0115.jpg: 384x640 (no detections), 7.5ms
# image 117/2219 /kaggle/working/test/game2_Clip1_0116.jpg: 384x640 (no detections), 7.4ms
# image 118/2219 /kaggle/working/test/game2_Clip1_0117.jpg: 384x640 (no detections), 7.5ms
# image 119/2219 /kaggle/working/test/game2_Clip1_0118.jpg: 384x640 1 ball, 7.5ms
# image 120/2219 /kaggle/working/test/game2_Clip1_0119.jpg: 384x640 (no detections), 7.5ms
# image 121/2219 /kaggle/working/test/game2_Clip1_0120.jpg: 384x640 1 ball, 7.5ms
# image 122/2219 /kaggle/working/test/game2_Clip1_0121.jpg: 384x640 1 ball, 7.5ms
# image 123/2219 /kaggle/working/test/game2_Clip1_0122.jpg: 384x640 1 ball, 7.5ms
# image 124/2219 /kaggle/working/test/game2_Clip1_0123.jpg: 384x640 1 ball, 7.5ms
# image 125/2219 /kaggle/working/test/game2_Clip1_0124.jpg: 384x640 1 ball, 7.5ms
# image 126/2219 /kaggle/working/test/game2_Clip1_0125.jpg: 384x640 1 ball, 7.5ms
# image 127/2219 /kaggle/working/test/game2_Clip1_0126.jpg: 384x640 1 ball, 7.5ms
# image 128/2219 /kaggle/working/test/game2_Clip1_0127.jpg: 384x640 1 ball, 7.5ms
# image 129/2219 /kaggle/working/test/game2_Clip1_0128.jpg: 384x640 1 ball, 7.5ms
# image 130/2219 /kaggle/working/test/game2_Clip1_0129.jpg: 384x640 (no detections), 7.5ms
# image 131/2219 /kaggle/working/test/game2_Clip1_0130.jpg: 384x640 1 ball, 7.5ms
# image 132/2219 /kaggle/working/test/game2_Clip1_0131.jpg: 384x640 1 ball, 7.5ms
# image 133/2219 /kaggle/working/test/game2_Clip1_0132.jpg: 384x640 1 ball, 7.5ms
# image 134/2219 /kaggle/working/test/game2_Clip1_0133.jpg: 384x640 1 ball, 7.5ms
# image 135/2219 /kaggle/working/test/game2_Clip1_0134.jpg: 384x640 1 ball, 7.5ms
# image 136/2219 /kaggle/working/test/game2_Clip1_0135.jpg: 384x640 1 ball, 7.5ms
# image 137/2219 /kaggle/working/test/game2_Clip1_0136.jpg: 384x640 1 ball, 7.5ms
# image 138/2219 /kaggle/working/test/game2_Clip1_0137.jpg: 384x640 1 ball, 7.5ms
# image 139/2219 /kaggle/working/test/game2_Clip1_0138.jpg: 384x640 1 ball, 7.5ms
# image 140/2219 /kaggle/working/test/game2_Clip1_0139.jpg: 384x640 1 ball, 7.5ms
# image 141/2219 /kaggle/working/test/game2_Clip1_0140.jpg: 384x640 1 ball, 7.5ms
# image 142/2219 /kaggle/working/test/game2_Clip1_0141.jpg: 384x640 1 ball, 7.5ms
# image 143/2219 /kaggle/working/test/game2_Clip1_0142.jpg: 384x640 1 ball, 7.5ms
# image 144/2219 /kaggle/working/test/game2_Clip1_0143.jpg: 384x640 1 ball, 7.5ms
# image 145/2219 /kaggle/working/test/game2_Clip1_0144.jpg: 384x640 1 ball, 7.5ms
# image 146/2219 /kaggle/working/test/game2_Clip1_0145.jpg: 384x640 1 ball, 7.5ms
# image 147/2219 /kaggle/working/test/game2_Clip1_0146.jpg: 384x640 1 ball, 7.5ms
# image 148/2219 /kaggle/working/test/game2_Clip1_0147.jpg: 384x640 1 ball, 7.5ms
# image 149/2219 /kaggle/working/test/game2_Clip1_0148.jpg: 384x640 1 ball, 7.5ms
# image 150/2219 /kaggle/working/test/game2_Clip1_0149.jpg: 384x640 1 ball, 7.5ms
# image 151/2219 /kaggle/working/test/game2_Clip1_0150.jpg: 384x640 1 ball, 7.5ms
# image 152/2219 /kaggle/working/test/game2_Clip1_0151.jpg: 384x640 1 ball, 7.5ms
# image 153/2219 /kaggle/working/test/game2_Clip1_0152.jpg: 384x640 2 balls, 7.5ms
# image 154/2219 /kaggle/working/test/game2_Clip1_0153.jpg: 384x640 1 ball, 8.8ms
# image 155/2219 /kaggle/working/test/game2_Clip1_0154.jpg: 384x640 1 ball, 7.5ms
# image 156/2219 /kaggle/working/test/game2_Clip1_0155.jpg: 384x640 1 ball, 7.5ms
# image 157/2219 /kaggle/working/test/game2_Clip1_0156.jpg: 384x640 1 ball, 7.5ms
# image 158/2219 /kaggle/working/test/game2_Clip1_0157.jpg: 384x640 1 ball, 8.0ms
# image 159/2219 /kaggle/working/test/game2_Clip1_0158.jpg: 384x640 1 ball, 7.5ms
# image 160/2219 /kaggle/working/test/game2_Clip1_0159.jpg: 384x640 1 ball, 7.5ms
# image 161/2219 /kaggle/working/test/game2_Clip1_0160.jpg: 384x640 1 ball, 7.5ms
# image 162/2219 /kaggle/working/test/game2_Clip1_0161.jpg: 384x640 (no detections), 7.5ms
# image 163/2219 /kaggle/working/test/game2_Clip1_0162.jpg: 384x640 (no detections), 7.5ms
# image 164/2219 /kaggle/working/test/game2_Clip1_0163.jpg: 384x640 (no detections), 7.5ms
# image 165/2219 /kaggle/working/test/game2_Clip1_0164.jpg: 384x640 (no detections), 7.5ms
# image 166/2219 /kaggle/working/test/game2_Clip1_0165.jpg: 384x640 1 ball, 7.5ms
# image 167/2219 /kaggle/working/test/game2_Clip1_0166.jpg: 384x640 1 ball, 7.5ms
# image 168/2219 /kaggle/working/test/game2_Clip1_0167.jpg: 384x640 2 balls, 7.5ms
# image 169/2219 /kaggle/working/test/game2_Clip1_0168.jpg: 384x640 1 ball, 7.5ms
# image 170/2219 /kaggle/working/test/game2_Clip1_0169.jpg: 384x640 1 ball, 7.5ms
# image 171/2219 /kaggle/working/test/game2_Clip1_0170.jpg: 384x640 1 ball, 7.5ms
# image 172/2219 /kaggle/working/test/game2_Clip1_0171.jpg: 384x640 (no detections), 7.5ms
# image 173/2219 /kaggle/working/test/game2_Clip1_0172.jpg: 384x640 (no detections), 7.5ms
# image 174/2219 /kaggle/working/test/game2_Clip1_0173.jpg: 384x640 (no detections), 7.5ms
# image 175/2219 /kaggle/working/test/game2_Clip1_0174.jpg: 384x640 (no detections), 7.5ms
# image 176/2219 /kaggle/working/test/game2_Clip1_0175.jpg: 384x640 1 ball, 7.5ms
# image 177/2219 /kaggle/working/test/game2_Clip1_0176.jpg: 384x640 1 ball, 7.5ms
# image 178/2219 /kaggle/working/test/game2_Clip1_0177.jpg: 384x640 1 ball, 7.5ms
# image 179/2219 /kaggle/working/test/game2_Clip1_0178.jpg: 384x640 1 ball, 7.5ms
# image 180/2219 /kaggle/working/test/game2_Clip1_0179.jpg: 384x640 1 ball, 7.5ms
# image 181/2219 /kaggle/working/test/game2_Clip1_0180.jpg: 384x640 1 ball, 7.5ms
# image 182/2219 /kaggle/working/test/game2_Clip1_0181.jpg: 384x640 1 ball, 7.5ms
# image 183/2219 /kaggle/working/test/game2_Clip1_0182.jpg: 384x640 1 ball, 7.5ms
# image 184/2219 /kaggle/working/test/game2_Clip1_0183.jpg: 384x640 (no detections), 7.5ms
# image 185/2219 /kaggle/working/test/game2_Clip1_0184.jpg: 384x640 1 ball, 7.5ms
# image 186/2219 /kaggle/working/test/game2_Clip1_0185.jpg: 384x640 2 balls, 7.5ms
# image 187/2219 /kaggle/working/test/game2_Clip1_0186.jpg: 384x640 1 ball, 7.5ms
# image 188/2219 /kaggle/working/test/game2_Clip1_0187.jpg: 384x640 1 ball, 7.5ms
# image 189/2219 /kaggle/working/test/game2_Clip1_0188.jpg: 384x640 1 ball, 7.5ms
# image 190/2219 /kaggle/working/test/game2_Clip1_0189.jpg: 384x640 (no detections), 7.5ms
# image 191/2219 /kaggle/working/test/game2_Clip1_0190.jpg: 384x640 (no detections), 7.5ms
# image 192/2219 /kaggle/working/test/game2_Clip1_0191.jpg: 384x640 1 ball, 7.5ms
# image 193/2219 /kaggle/working/test/game2_Clip1_0192.jpg: 384x640 1 ball, 7.5ms
# image 194/2219 /kaggle/working/test/game2_Clip1_0193.jpg: 384x640 1 ball, 7.5ms
# image 195/2219 /kaggle/working/test/game2_Clip1_0194.jpg: 384x640 2 balls, 7.5ms
# image 196/2219 /kaggle/working/test/game2_Clip1_0195.jpg: 384x640 1 ball, 7.5ms
# image 197/2219 /kaggle/working/test/game2_Clip1_0196.jpg: 384x640 2 balls, 7.5ms
# image 198/2219 /kaggle/working/test/game2_Clip1_0197.jpg: 384x640 1 ball, 7.5ms
# image 199/2219 /kaggle/working/test/game2_Clip1_0198.jpg: 384x640 1 ball, 7.5ms
# image 200/2219 /kaggle/working/test/game2_Clip1_0199.jpg: 384x640 1 ball, 7.5ms
# image 201/2219 /kaggle/working/test/game2_Clip1_0200.jpg: 384x640 1 ball, 7.5ms
# image 202/2219 /kaggle/working/test/game2_Clip1_0201.jpg: 384x640 1 ball, 7.5ms
# image 203/2219 /kaggle/working/test/game2_Clip1_0202.jpg: 384x640 1 ball, 7.4ms
# image 204/2219 /kaggle/working/test/game2_Clip1_0203.jpg: 384x640 1 ball, 7.5ms
# image 205/2219 /kaggle/working/test/game2_Clip1_0204.jpg: 384x640 1 ball, 7.5ms
# image 206/2219 /kaggle/working/test/game2_Clip1_0205.jpg: 384x640 1 ball, 7.5ms
# image 207/2219 /kaggle/working/test/game2_Clip1_0206.jpg: 384x640 1 ball, 7.5ms
# image 208/2219 /kaggle/working/test/game2_Clip1_0207.jpg: 384x640 1 ball, 7.5ms
# image 209/2219 /kaggle/working/test/game2_Clip1_0208.jpg: 384x640 1 ball, 7.5ms
# image 210/2219 /kaggle/working/test/game2_Clip1_0209.jpg: 384x640 2 balls, 7.5ms
# image 211/2219 /kaggle/working/test/game2_Clip1_0210.jpg: 384x640 2 balls, 7.5ms
# image 212/2219 /kaggle/working/test/game2_Clip1_0211.jpg: 384x640 2 balls, 7.5ms
# image 213/2219 /kaggle/working/test/game2_Clip1_0212.jpg: 384x640 1 ball, 7.5ms
# image 214/2219 /kaggle/working/test/game2_Clip1_0213.jpg: 384x640 1 ball, 7.5ms
# image 215/2219 /kaggle/working/test/game2_Clip1_0214.jpg: 384x640 1 ball, 7.5ms
# image 216/2219 /kaggle/working/test/game2_Clip1_0215.jpg: 384x640 1 ball, 7.5ms
# image 217/2219 /kaggle/working/test/game2_Clip1_0216.jpg: 384x640 1 ball, 7.5ms
# image 218/2219 /kaggle/working/test/game2_Clip1_0217.jpg: 384x640 1 ball, 7.5ms
# image 219/2219 /kaggle/working/test/game2_Clip1_0218.jpg: 384x640 1 ball, 7.5ms
# image 220/2219 /kaggle/working/test/game2_Clip1_0219.jpg: 384x640 1 ball, 7.5ms
# image 221/2219 /kaggle/working/test/game2_Clip1_0220.jpg: 384x640 1 ball, 7.5ms
# image 222/2219 /kaggle/working/test/game2_Clip1_0221.jpg: 384x640 1 ball, 7.5ms
# image 223/2219 /kaggle/working/test/game2_Clip1_0222.jpg: 384x640 1 ball, 7.5ms
# image 224/2219 /kaggle/working/test/game2_Clip1_0223.jpg: 384x640 1 ball, 7.5ms
# image 225/2219 /kaggle/working/test/game2_Clip1_0224.jpg: 384x640 1 ball, 7.5ms
# image 226/2219 /kaggle/working/test/game2_Clip1_0225.jpg: 384x640 1 ball, 7.4ms
# image 227/2219 /kaggle/working/test/game2_Clip1_0226.jpg: 384x640 1 ball, 7.5ms
# image 228/2219 /kaggle/working/test/game2_Clip1_0227.jpg: 384x640 1 ball, 7.5ms
# image 229/2219 /kaggle/working/test/game2_Clip1_0228.jpg: 384x640 1 ball, 7.5ms
# image 230/2219 /kaggle/working/test/game2_Clip1_0229.jpg: 384x640 1 ball, 7.5ms
# image 231/2219 /kaggle/working/test/game2_Clip1_0230.jpg: 384x640 1 ball, 7.5ms
# image 232/2219 /kaggle/working/test/game2_Clip1_0231.jpg: 384x640 1 ball, 7.5ms
# image 233/2219 /kaggle/working/test/game2_Clip1_0232.jpg: 384x640 (no detections), 7.5ms
# image 234/2219 /kaggle/working/test/game2_Clip1_0233.jpg: 384x640 (no detections), 7.5ms
# image 235/2219 /kaggle/working/test/game2_Clip1_0234.jpg: 384x640 (no detections), 7.5ms
# image 236/2219 /kaggle/working/test/game2_Clip1_0235.jpg: 384x640 (no detections), 7.5ms
# image 237/2219 /kaggle/working/test/game2_Clip1_0236.jpg: 384x640 1 ball, 7.5ms
# image 238/2219 /kaggle/working/test/game2_Clip1_0237.jpg: 384x640 (no detections), 7.5ms
# image 239/2219 /kaggle/working/test/game2_Clip1_0238.jpg: 384x640 1 ball, 7.5ms
# image 240/2219 /kaggle/working/test/game2_Clip1_0239.jpg: 384x640 1 ball, 7.5ms
# image 241/2219 /kaggle/working/test/game2_Clip1_0240.jpg: 384x640 1 ball, 7.5ms
# image 242/2219 /kaggle/working/test/game2_Clip1_0241.jpg: 384x640 1 ball, 7.5ms
# image 243/2219 /kaggle/working/test/game2_Clip1_0242.jpg: 384x640 1 ball, 7.5ms
# image 244/2219 /kaggle/working/test/game2_Clip1_0243.jpg: 384x640 1 ball, 7.5ms
# image 245/2219 /kaggle/working/test/game2_Clip1_0244.jpg: 384x640 1 ball, 7.5ms
# image 246/2219 /kaggle/working/test/game2_Clip1_0245.jpg: 384x640 1 ball, 7.5ms
# image 247/2219 /kaggle/working/test/game2_Clip1_0246.jpg: 384x640 1 ball, 7.5ms
# image 248/2219 /kaggle/working/test/game2_Clip1_0247.jpg: 384x640 1 ball, 7.5ms
# image 249/2219 /kaggle/working/test/game2_Clip1_0248.jpg: 384x640 (no detections), 7.5ms
# image 250/2219 /kaggle/working/test/game2_Clip1_0249.jpg: 384x640 1 ball, 7.5ms
# image 251/2219 /kaggle/working/test/game2_Clip1_0250.jpg: 384x640 1 ball, 7.5ms
# image 252/2219 /kaggle/working/test/game2_Clip1_0251.jpg: 384x640 1 ball, 7.5ms
# image 253/2219 /kaggle/working/test/game2_Clip1_0252.jpg: 384x640 2 balls, 7.5ms
# image 254/2219 /kaggle/working/test/game2_Clip1_0253.jpg: 384x640 1 ball, 7.5ms
# image 255/2219 /kaggle/working/test/game2_Clip1_0254.jpg: 384x640 1 ball, 7.4ms
# image 256/2219 /kaggle/working/test/game2_Clip1_0255.jpg: 384x640 1 ball, 7.5ms
# image 257/2219 /kaggle/working/test/game2_Clip1_0256.jpg: 384x640 1 ball, 7.5ms
# image 258/2219 /kaggle/working/test/game2_Clip1_0257.jpg: 384x640 1 ball, 7.5ms
# image 259/2219 /kaggle/working/test/game2_Clip1_0258.jpg: 384x640 1 ball, 7.5ms
# image 260/2219 /kaggle/working/test/game2_Clip1_0259.jpg: 384x640 1 ball, 7.5ms
# image 261/2219 /kaggle/working/test/game2_Clip1_0260.jpg: 384x640 1 ball, 7.5ms
# image 262/2219 /kaggle/working/test/game2_Clip1_0261.jpg: 384x640 1 ball, 7.5ms
# image 263/2219 /kaggle/working/test/game2_Clip1_0262.jpg: 384x640 1 ball, 7.5ms
# image 264/2219 /kaggle/working/test/game2_Clip1_0263.jpg: 384x640 1 ball, 7.5ms
# image 265/2219 /kaggle/working/test/game2_Clip1_0264.jpg: 384x640 1 ball, 7.5ms
# image 266/2219 /kaggle/working/test/game2_Clip1_0265.jpg: 384x640 1 ball, 7.5ms
# image 267/2219 /kaggle/working/test/game2_Clip1_0266.jpg: 384x640 (no detections), 7.5ms
# image 268/2219 /kaggle/working/test/game2_Clip1_0267.jpg: 384x640 (no detections), 7.5ms
# image 269/2219 /kaggle/working/test/game2_Clip1_0268.jpg: 384x640 1 ball, 7.5ms
# image 270/2219 /kaggle/working/test/game2_Clip1_0269.jpg: 384x640 1 ball, 7.5ms
# image 271/2219 /kaggle/working/test/game2_Clip1_0270.jpg: 384x640 (no detections), 7.5ms
# image 272/2219 /kaggle/working/test/game2_Clip1_0271.jpg: 384x640 (no detections), 7.5ms
# image 273/2219 /kaggle/working/test/game2_Clip1_0272.jpg: 384x640 (no detections), 7.4ms
# image 274/2219 /kaggle/working/test/game2_Clip1_0273.jpg: 384x640 1 ball, 7.5ms
# image 275/2219 /kaggle/working/test/game2_Clip1_0274.jpg: 384x640 1 ball, 7.5ms
# image 276/2219 /kaggle/working/test/game2_Clip1_0275.jpg: 384x640 1 ball, 7.5ms
# image 277/2219 /kaggle/working/test/game2_Clip1_0276.jpg: 384x640 1 ball, 7.4ms
# image 278/2219 /kaggle/working/test/game2_Clip1_0277.jpg: 384x640 1 ball, 7.5ms
# image 279/2219 /kaggle/working/test/game2_Clip1_0278.jpg: 384x640 1 ball, 7.5ms
# image 280/2219 /kaggle/working/test/game2_Clip1_0279.jpg: 384x640 1 ball, 7.5ms
# image 281/2219 /kaggle/working/test/game2_Clip1_0280.jpg: 384x640 1 ball, 7.5ms
# image 282/2219 /kaggle/working/test/game2_Clip1_0281.jpg: 384x640 1 ball, 7.5ms
# image 283/2219 /kaggle/working/test/game2_Clip1_0282.jpg: 384x640 1 ball, 7.5ms
# image 284/2219 /kaggle/working/test/game2_Clip1_0283.jpg: 384x640 1 ball, 7.4ms
# image 285/2219 /kaggle/working/test/game2_Clip1_0284.jpg: 384x640 1 ball, 7.5ms
# image 286/2219 /kaggle/working/test/game2_Clip1_0285.jpg: 384x640 2 balls, 7.5ms
# image 287/2219 /kaggle/working/test/game2_Clip1_0286.jpg: 384x640 2 balls, 7.5ms
# image 288/2219 /kaggle/working/test/game2_Clip1_0287.jpg: 384x640 2 balls, 7.5ms
# image 289/2219 /kaggle/working/test/game2_Clip1_0288.jpg: 384x640 2 balls, 7.5ms
# image 290/2219 /kaggle/working/test/game2_Clip1_0289.jpg: 384x640 2 balls, 7.5ms
# image 291/2219 /kaggle/working/test/game2_Clip1_0290.jpg: 384x640 2 balls, 7.5ms
# image 292/2219 /kaggle/working/test/game2_Clip1_0291.jpg: 384x640 1 ball, 7.5ms
# image 293/2219 /kaggle/working/test/game2_Clip1_0292.jpg: 384x640 2 balls, 7.5ms
# image 294/2219 /kaggle/working/test/game2_Clip1_0293.jpg: 384x640 1 ball, 7.5ms
# image 295/2219 /kaggle/working/test/game2_Clip1_0294.jpg: 384x640 1 ball, 7.5ms
# image 296/2219 /kaggle/working/test/game2_Clip1_0295.jpg: 384x640 2 balls, 7.5ms
# image 297/2219 /kaggle/working/test/game2_Clip1_0296.jpg: 384x640 2 balls, 7.5ms
# image 298/2219 /kaggle/working/test/game2_Clip1_0297.jpg: 384x640 1 ball, 7.5ms
# image 299/2219 /kaggle/working/test/game2_Clip1_0298.jpg: 384x640 1 ball, 7.5ms
# image 300/2219 /kaggle/working/test/game2_Clip1_0299.jpg: 384x640 1 ball, 7.5ms
# image 301/2219 /kaggle/working/test/game2_Clip1_0300.jpg: 384x640 2 balls, 7.5ms
# image 302/2219 /kaggle/working/test/game2_Clip1_0301.jpg: 384x640 1 ball, 7.5ms
# image 303/2219 /kaggle/working/test/game2_Clip1_0302.jpg: 384x640 1 ball, 7.5ms
# image 304/2219 /kaggle/working/test/game2_Clip1_0303.jpg: 384x640 1 ball, 7.5ms
# image 305/2219 /kaggle/working/test/game2_Clip1_0304.jpg: 384x640 1 ball, 7.5ms
# image 306/2219 /kaggle/working/test/game2_Clip1_0305.jpg: 384x640 1 ball, 7.5ms
# image 307/2219 /kaggle/working/test/game2_Clip1_0306.jpg: 384x640 1 ball, 7.5ms
# image 308/2219 /kaggle/working/test/game2_Clip1_0307.jpg: 384x640 1 ball, 7.5ms
# image 309/2219 /kaggle/working/test/game2_Clip1_0308.jpg: 384x640 1 ball, 7.5ms
# image 310/2219 /kaggle/working/test/game2_Clip1_0309.jpg: 384x640 (no detections), 7.4ms
# image 311/2219 /kaggle/working/test/game2_Clip1_0310.jpg: 384x640 1 ball, 7.5ms
# image 312/2219 /kaggle/working/test/game2_Clip1_0311.jpg: 384x640 (no detections), 7.5ms
# image 313/2219 /kaggle/working/test/game2_Clip1_0312.jpg: 384x640 1 ball, 7.5ms
# image 314/2219 /kaggle/working/test/game2_Clip1_0313.jpg: 384x640 2 balls, 7.5ms
# image 315/2219 /kaggle/working/test/game2_Clip1_0314.jpg: 384x640 2 balls, 7.5ms
# image 316/2219 /kaggle/working/test/game2_Clip1_0315.jpg: 384x640 2 balls, 7.5ms
# image 317/2219 /kaggle/working/test/game2_Clip1_0316.jpg: 384x640 1 ball, 7.5ms
# image 318/2219 /kaggle/working/test/game2_Clip1_0317.jpg: 384x640 1 ball, 7.5ms
# image 319/2219 /kaggle/working/test/game2_Clip1_0318.jpg: 384x640 1 ball, 7.5ms
# image 320/2219 /kaggle/working/test/game2_Clip1_0319.jpg: 384x640 1 ball, 7.5ms
# image 321/2219 /kaggle/working/test/game2_Clip1_0320.jpg: 384x640 1 ball, 7.5ms
# image 322/2219 /kaggle/working/test/game2_Clip1_0321.jpg: 384x640 1 ball, 7.5ms
# image 323/2219 /kaggle/working/test/game2_Clip1_0322.jpg: 384x640 1 ball, 7.5ms
# image 324/2219 /kaggle/working/test/game2_Clip1_0323.jpg: 384x640 1 ball, 7.5ms
# image 325/2219 /kaggle/working/test/game2_Clip1_0324.jpg: 384x640 1 ball, 7.5ms
# image 326/2219 /kaggle/working/test/game2_Clip1_0325.jpg: 384x640 1 ball, 7.5ms
# image 327/2219 /kaggle/working/test/game2_Clip1_0326.jpg: 384x640 1 ball, 7.5ms
# image 328/2219 /kaggle/working/test/game2_Clip1_0327.jpg: 384x640 1 ball, 7.5ms
# image 329/2219 /kaggle/working/test/game2_Clip1_0328.jpg: 384x640 1 ball, 7.5ms
# image 330/2219 /kaggle/working/test/game2_Clip1_0329.jpg: 384x640 1 ball, 7.5ms
# image 331/2219 /kaggle/working/test/game2_Clip1_0330.jpg: 384x640 1 ball, 7.5ms
# image 332/2219 /kaggle/working/test/game2_Clip1_0331.jpg: 384x640 1 ball, 7.5ms
# image 333/2219 /kaggle/working/test/game2_Clip1_0332.jpg: 384x640 1 ball, 7.5ms
# image 334/2219 /kaggle/working/test/game2_Clip1_0333.jpg: 384x640 (no detections), 7.5ms
# image 335/2219 /kaggle/working/test/game2_Clip1_0334.jpg: 384x640 1 ball, 7.5ms
# image 336/2219 /kaggle/working/test/game2_Clip1_0335.jpg: 384x640 1 ball, 7.5ms
# image 337/2219 /kaggle/working/test/game2_Clip1_0336.jpg: 384x640 1 ball, 7.5ms
# image 338/2219 /kaggle/working/test/game2_Clip1_0337.jpg: 384x640 1 ball, 7.5ms
# image 339/2219 /kaggle/working/test/game2_Clip1_0338.jpg: 384x640 1 ball, 7.5ms
# image 340/2219 /kaggle/working/test/game2_Clip1_0339.jpg: 384x640 1 ball, 7.5ms
# image 341/2219 /kaggle/working/test/game2_Clip1_0340.jpg: 384x640 1 ball, 7.4ms
# image 342/2219 /kaggle/working/test/game2_Clip1_0341.jpg: 384x640 1 ball, 7.5ms
# image 343/2219 /kaggle/working/test/game2_Clip1_0342.jpg: 384x640 1 ball, 7.5ms
# image 344/2219 /kaggle/working/test/game2_Clip1_0343.jpg: 384x640 (no detections), 7.5ms
# image 345/2219 /kaggle/working/test/game2_Clip1_0344.jpg: 384x640 1 ball, 7.5ms
# image 346/2219 /kaggle/working/test/game2_Clip1_0345.jpg: 384x640 (no detections), 7.5ms
# image 347/2219 /kaggle/working/test/game2_Clip1_0346.jpg: 384x640 (no detections), 7.5ms
# image 348/2219 /kaggle/working/test/game2_Clip1_0347.jpg: 384x640 1 ball, 7.5ms
# image 349/2219 /kaggle/working/test/game2_Clip1_0348.jpg: 384x640 1 ball, 7.5ms
# image 350/2219 /kaggle/working/test/game2_Clip1_0349.jpg: 384x640 1 ball, 7.5ms
# image 351/2219 /kaggle/working/test/game2_Clip1_0350.jpg: 384x640 1 ball, 7.5ms
# image 352/2219 /kaggle/working/test/game2_Clip1_0351.jpg: 384x640 1 ball, 7.5ms
# image 353/2219 /kaggle/working/test/game2_Clip1_0352.jpg: 384x640 1 ball, 7.4ms
# image 354/2219 /kaggle/working/test/game2_Clip1_0353.jpg: 384x640 1 ball, 7.5ms
# image 355/2219 /kaggle/working/test/game2_Clip1_0354.jpg: 384x640 1 ball, 7.5ms
# image 356/2219 /kaggle/working/test/game2_Clip1_0355.jpg: 384x640 1 ball, 7.5ms
# image 357/2219 /kaggle/working/test/game2_Clip1_0356.jpg: 384x640 (no detections), 7.5ms
# image 358/2219 /kaggle/working/test/game2_Clip1_0357.jpg: 384x640 1 ball, 7.5ms
# image 359/2219 /kaggle/working/test/game2_Clip1_0358.jpg: 384x640 1 ball, 7.5ms
# image 360/2219 /kaggle/working/test/game2_Clip1_0359.jpg: 384x640 1 ball, 7.5ms
# image 361/2219 /kaggle/working/test/game2_Clip1_0360.jpg: 384x640 1 ball, 7.5ms
# image 362/2219 /kaggle/working/test/game2_Clip2_0000.jpg: 384x640 (no detections), 7.5ms
# image 363/2219 /kaggle/working/test/game2_Clip2_0001.jpg: 384x640 (no detections), 7.5ms
# image 364/2219 /kaggle/working/test/game2_Clip2_0002.jpg: 384x640 (no detections), 7.4ms
# image 365/2219 /kaggle/working/test/game2_Clip2_0003.jpg: 384x640 1 ball, 7.5ms
# image 366/2219 /kaggle/working/test/game2_Clip2_0004.jpg: 384x640 1 ball, 7.5ms
# image 367/2219 /kaggle/working/test/game2_Clip2_0005.jpg: 384x640 1 ball, 7.5ms
# image 368/2219 /kaggle/working/test/game2_Clip2_0006.jpg: 384x640 (no detections), 7.5ms
# image 369/2219 /kaggle/working/test/game2_Clip2_0007.jpg: 384x640 (no detections), 7.5ms
# image 370/2219 /kaggle/working/test/game2_Clip2_0008.jpg: 384x640 1 ball, 7.5ms
# image 371/2219 /kaggle/working/test/game2_Clip2_0009.jpg: 384x640 1 ball, 7.5ms
# image 372/2219 /kaggle/working/test/game2_Clip2_0010.jpg: 384x640 1 ball, 7.5ms
# image 373/2219 /kaggle/working/test/game2_Clip2_0011.jpg: 384x640 1 ball, 7.5ms
# image 374/2219 /kaggle/working/test/game2_Clip2_0012.jpg: 384x640 1 ball, 7.5ms
# image 375/2219 /kaggle/working/test/game2_Clip2_0013.jpg: 384x640 1 ball, 7.5ms
# image 376/2219 /kaggle/working/test/game2_Clip2_0014.jpg: 384x640 1 ball, 7.5ms
# image 377/2219 /kaggle/working/test/game2_Clip2_0015.jpg: 384x640 2 balls, 7.5ms
# image 378/2219 /kaggle/working/test/game2_Clip2_0016.jpg: 384x640 1 ball, 7.5ms
# image 379/2219 /kaggle/working/test/game2_Clip2_0017.jpg: 384x640 1 ball, 7.5ms
# image 380/2219 /kaggle/working/test/game2_Clip2_0018.jpg: 384x640 (no detections), 7.5ms
# image 381/2219 /kaggle/working/test/game2_Clip2_0019.jpg: 384x640 2 balls, 7.5ms
# image 382/2219 /kaggle/working/test/game2_Clip2_0020.jpg: 384x640 (no detections), 7.5ms
# image 383/2219 /kaggle/working/test/game2_Clip2_0021.jpg: 384x640 (no detections), 7.5ms
# image 384/2219 /kaggle/working/test/game2_Clip2_0022.jpg: 384x640 1 ball, 7.5ms
# image 385/2219 /kaggle/working/test/game2_Clip2_0023.jpg: 384x640 (no detections), 7.5ms
# image 386/2219 /kaggle/working/test/game2_Clip2_0024.jpg: 384x640 (no detections), 7.5ms
# image 387/2219 /kaggle/working/test/game2_Clip2_0025.jpg: 384x640 (no detections), 7.5ms
# image 388/2219 /kaggle/working/test/game2_Clip2_0026.jpg: 384x640 1 ball, 7.5ms
# image 389/2219 /kaggle/working/test/game2_Clip2_0027.jpg: 384x640 (no detections), 7.5ms
# image 390/2219 /kaggle/working/test/game2_Clip2_0028.jpg: 384x640 1 ball, 7.5ms
# image 391/2219 /kaggle/working/test/game2_Clip2_0029.jpg: 384x640 1 ball, 7.5ms
# image 392/2219 /kaggle/working/test/game2_Clip2_0030.jpg: 384x640 1 ball, 7.5ms
# image 393/2219 /kaggle/working/test/game2_Clip2_0031.jpg: 384x640 1 ball, 7.5ms
# image 394/2219 /kaggle/working/test/game2_Clip2_0032.jpg: 384x640 (no detections), 7.5ms
# image 395/2219 /kaggle/working/test/game2_Clip2_0033.jpg: 384x640 1 ball, 7.9ms
# image 396/2219 /kaggle/working/test/game2_Clip2_0034.jpg: 384x640 1 ball, 7.5ms
# image 397/2219 /kaggle/working/test/game2_Clip2_0035.jpg: 384x640 1 ball, 7.5ms
# image 398/2219 /kaggle/working/test/game2_Clip2_0036.jpg: 384x640 1 ball, 7.5ms
# image 399/2219 /kaggle/working/test/game2_Clip2_0037.jpg: 384x640 1 ball, 7.5ms
# image 400/2219 /kaggle/working/test/game2_Clip2_0038.jpg: 384x640 1 ball, 7.5ms
# image 401/2219 /kaggle/working/test/game2_Clip2_0039.jpg: 384x640 1 ball, 7.5ms
# image 402/2219 /kaggle/working/test/game2_Clip2_0040.jpg: 384x640 1 ball, 7.5ms
# image 403/2219 /kaggle/working/test/game2_Clip2_0041.jpg: 384x640 1 ball, 7.5ms
# image 404/2219 /kaggle/working/test/game2_Clip2_0042.jpg: 384x640 1 ball, 7.5ms
# image 405/2219 /kaggle/working/test/game2_Clip2_0043.jpg: 384x640 1 ball, 7.5ms
# image 406/2219 /kaggle/working/test/game2_Clip2_0044.jpg: 384x640 1 ball, 7.5ms
# image 407/2219 /kaggle/working/test/game2_Clip2_0045.jpg: 384x640 1 ball, 7.5ms
# image 408/2219 /kaggle/working/test/game2_Clip2_0046.jpg: 384x640 1 ball, 7.5ms
# image 409/2219 /kaggle/working/test/game2_Clip2_0047.jpg: 384x640 1 ball, 7.5ms
# image 410/2219 /kaggle/working/test/game2_Clip2_0048.jpg: 384x640 1 ball, 7.5ms
# image 411/2219 /kaggle/working/test/game2_Clip2_0049.jpg: 384x640 1 ball, 7.5ms
# image 412/2219 /kaggle/working/test/game2_Clip2_0050.jpg: 384x640 1 ball, 7.5ms
# image 413/2219 /kaggle/working/test/game2_Clip2_0051.jpg: 384x640 1 ball, 7.5ms
# image 414/2219 /kaggle/working/test/game2_Clip2_0052.jpg: 384x640 1 ball, 7.5ms
# image 415/2219 /kaggle/working/test/game2_Clip2_0053.jpg: 384x640 1 ball, 7.5ms
# image 416/2219 /kaggle/working/test/game2_Clip2_0054.jpg: 384x640 1 ball, 7.5ms
# image 417/2219 /kaggle/working/test/game2_Clip2_0055.jpg: 384x640 1 ball, 7.5ms
# image 418/2219 /kaggle/working/test/game2_Clip2_0056.jpg: 384x640 1 ball, 7.5ms
# image 419/2219 /kaggle/working/test/game2_Clip2_0057.jpg: 384x640 1 ball, 8.8ms
# image 420/2219 /kaggle/working/test/game2_Clip2_0058.jpg: 384x640 1 ball, 7.5ms
# image 421/2219 /kaggle/working/test/game2_Clip2_0059.jpg: 384x640 1 ball, 7.5ms
# image 422/2219 /kaggle/working/test/game2_Clip2_0060.jpg: 384x640 1 ball, 7.5ms
# image 423/2219 /kaggle/working/test/game2_Clip2_0061.jpg: 384x640 1 ball, 7.9ms
# image 424/2219 /kaggle/working/test/game2_Clip2_0062.jpg: 384x640 1 ball, 7.5ms
# image 425/2219 /kaggle/working/test/game2_Clip2_0063.jpg: 384x640 1 ball, 7.5ms
# image 426/2219 /kaggle/working/test/game2_Clip2_0064.jpg: 384x640 1 ball, 7.5ms
# image 427/2219 /kaggle/working/test/game2_Clip2_0065.jpg: 384x640 (no detections), 7.5ms
# image 428/2219 /kaggle/working/test/game2_Clip2_0066.jpg: 384x640 (no detections), 7.5ms
# image 429/2219 /kaggle/working/test/game2_Clip2_0067.jpg: 384x640 1 ball, 7.5ms
# image 430/2219 /kaggle/working/test/game2_Clip2_0068.jpg: 384x640 1 ball, 7.5ms
# image 431/2219 /kaggle/working/test/game2_Clip2_0069.jpg: 384x640 1 ball, 7.5ms
# image 432/2219 /kaggle/working/test/game2_Clip2_0070.jpg: 384x640 1 ball, 7.5ms
# image 433/2219 /kaggle/working/test/game2_Clip2_0071.jpg: 384x640 1 ball, 7.5ms
# image 434/2219 /kaggle/working/test/game2_Clip2_0072.jpg: 384x640 1 ball, 7.5ms
# image 435/2219 /kaggle/working/test/game2_Clip2_0073.jpg: 384x640 1 ball, 7.5ms
# image 436/2219 /kaggle/working/test/game2_Clip2_0074.jpg: 384x640 1 ball, 7.5ms
# image 437/2219 /kaggle/working/test/game2_Clip2_0075.jpg: 384x640 1 ball, 7.5ms
# image 438/2219 /kaggle/working/test/game2_Clip2_0076.jpg: 384x640 1 ball, 7.5ms
# image 439/2219 /kaggle/working/test/game2_Clip2_0077.jpg: 384x640 1 ball, 7.5ms
# image 440/2219 /kaggle/working/test/game2_Clip2_0078.jpg: 384x640 1 ball, 7.5ms
# image 441/2219 /kaggle/working/test/game2_Clip2_0079.jpg: 384x640 1 ball, 7.5ms
# image 442/2219 /kaggle/working/test/game2_Clip2_0080.jpg: 384x640 1 ball, 7.5ms
# image 443/2219 /kaggle/working/test/game2_Clip2_0081.jpg: 384x640 1 ball, 7.5ms
# image 444/2219 /kaggle/working/test/game2_Clip2_0082.jpg: 384x640 1 ball, 7.5ms
# image 445/2219 /kaggle/working/test/game2_Clip2_0083.jpg: 384x640 1 ball, 7.5ms
# image 446/2219 /kaggle/working/test/game2_Clip2_0084.jpg: 384x640 1 ball, 7.5ms
# image 447/2219 /kaggle/working/test/game2_Clip2_0085.jpg: 384x640 1 ball, 7.5ms
# image 448/2219 /kaggle/working/test/game2_Clip2_0086.jpg: 384x640 1 ball, 7.5ms
# image 449/2219 /kaggle/working/test/game2_Clip2_0087.jpg: 384x640 1 ball, 7.5ms
# image 450/2219 /kaggle/working/test/game2_Clip2_0088.jpg: 384x640 1 ball, 7.5ms
# image 451/2219 /kaggle/working/test/game2_Clip2_0089.jpg: 384x640 1 ball, 7.5ms
# image 452/2219 /kaggle/working/test/game2_Clip2_0090.jpg: 384x640 1 ball, 7.5ms
# image 453/2219 /kaggle/working/test/game2_Clip2_0091.jpg: 384x640 1 ball, 7.5ms
# image 454/2219 /kaggle/working/test/game2_Clip2_0092.jpg: 384x640 1 ball, 7.5ms
# image 455/2219 /kaggle/working/test/game2_Clip2_0093.jpg: 384x640 1 ball, 7.5ms
# image 456/2219 /kaggle/working/test/game2_Clip2_0094.jpg: 384x640 (no detections), 7.5ms
# image 457/2219 /kaggle/working/test/game2_Clip2_0095.jpg: 384x640 1 ball, 7.5ms
# image 458/2219 /kaggle/working/test/game2_Clip2_0096.jpg: 384x640 1 ball, 7.5ms
# image 459/2219 /kaggle/working/test/game2_Clip2_0097.jpg: 384x640 1 ball, 7.5ms
# image 460/2219 /kaggle/working/test/game2_Clip2_0098.jpg: 384x640 1 ball, 7.5ms
# image 461/2219 /kaggle/working/test/game2_Clip2_0099.jpg: 384x640 1 ball, 7.5ms
# image 462/2219 /kaggle/working/test/game2_Clip2_0100.jpg: 384x640 1 ball, 7.5ms
# image 463/2219 /kaggle/working/test/game2_Clip2_0101.jpg: 384x640 1 ball, 7.5ms
# image 464/2219 /kaggle/working/test/game2_Clip2_0102.jpg: 384x640 1 ball, 7.5ms
# image 465/2219 /kaggle/working/test/game2_Clip2_0103.jpg: 384x640 1 ball, 7.4ms
# image 466/2219 /kaggle/working/test/game2_Clip2_0104.jpg: 384x640 1 ball, 7.5ms
# image 467/2219 /kaggle/working/test/game2_Clip2_0105.jpg: 384x640 1 ball, 7.5ms
# image 468/2219 /kaggle/working/test/game2_Clip2_0106.jpg: 384x640 1 ball, 7.5ms
# image 469/2219 /kaggle/working/test/game2_Clip2_0107.jpg: 384x640 1 ball, 7.4ms
# image 470/2219 /kaggle/working/test/game2_Clip2_0108.jpg: 384x640 1 ball, 7.5ms
# image 471/2219 /kaggle/working/test/game2_Clip2_0109.jpg: 384x640 1 ball, 7.5ms
# image 472/2219 /kaggle/working/test/game2_Clip2_0110.jpg: 384x640 1 ball, 7.5ms
# image 473/2219 /kaggle/working/test/game2_Clip2_0111.jpg: 384x640 1 ball, 7.5ms
# image 474/2219 /kaggle/working/test/game2_Clip2_0112.jpg: 384x640 1 ball, 7.5ms
# image 475/2219 /kaggle/working/test/game2_Clip2_0113.jpg: 384x640 1 ball, 7.5ms
# image 476/2219 /kaggle/working/test/game2_Clip2_0114.jpg: 384x640 1 ball, 7.5ms
# image 477/2219 /kaggle/working/test/game2_Clip2_0115.jpg: 384x640 1 ball, 7.5ms
# image 478/2219 /kaggle/working/test/game2_Clip2_0116.jpg: 384x640 1 ball, 7.5ms
# image 479/2219 /kaggle/working/test/game2_Clip2_0117.jpg: 384x640 1 ball, 7.5ms
# image 480/2219 /kaggle/working/test/game2_Clip2_0118.jpg: 384x640 1 ball, 7.5ms
# image 481/2219 /kaggle/working/test/game2_Clip2_0119.jpg: 384x640 1 ball, 7.5ms
# image 482/2219 /kaggle/working/test/game2_Clip2_0120.jpg: 384x640 1 ball, 7.5ms
# image 483/2219 /kaggle/working/test/game2_Clip2_0121.jpg: 384x640 1 ball, 7.5ms
# image 484/2219 /kaggle/working/test/game2_Clip2_0122.jpg: 384x640 1 ball, 7.5ms
# image 485/2219 /kaggle/working/test/game2_Clip2_0123.jpg: 384x640 1 ball, 7.5ms
# image 486/2219 /kaggle/working/test/game2_Clip2_0124.jpg: 384x640 1 ball, 7.5ms
# image 487/2219 /kaggle/working/test/game2_Clip2_0125.jpg: 384x640 1 ball, 7.5ms
# image 488/2219 /kaggle/working/test/game2_Clip2_0126.jpg: 384x640 1 ball, 7.5ms
# image 489/2219 /kaggle/working/test/game2_Clip2_0127.jpg: 384x640 1 ball, 7.5ms
# image 490/2219 /kaggle/working/test/game2_Clip2_0128.jpg: 384x640 1 ball, 7.5ms
# image 491/2219 /kaggle/working/test/game2_Clip2_0129.jpg: 384x640 1 ball, 7.5ms
# image 492/2219 /kaggle/working/test/game2_Clip2_0130.jpg: 384x640 1 ball, 7.5ms
# image 493/2219 /kaggle/working/test/game2_Clip2_0131.jpg: 384x640 1 ball, 7.5ms
# image 494/2219 /kaggle/working/test/game2_Clip2_0132.jpg: 384x640 1 ball, 7.5ms
# image 495/2219 /kaggle/working/test/game2_Clip2_0133.jpg: 384x640 1 ball, 7.5ms
# image 496/2219 /kaggle/working/test/game2_Clip2_0134.jpg: 384x640 1 ball, 7.5ms
# image 497/2219 /kaggle/working/test/game2_Clip2_0135.jpg: 384x640 1 ball, 7.4ms
# image 498/2219 /kaggle/working/test/game2_Clip2_0136.jpg: 384x640 (no detections), 7.5ms
# image 499/2219 /kaggle/working/test/game2_Clip2_0137.jpg: 384x640 (no detections), 7.5ms
# image 500/2219 /kaggle/working/test/game2_Clip2_0138.jpg: 384x640 1 ball, 7.5ms
# image 501/2219 /kaggle/working/test/game2_Clip2_0139.jpg: 384x640 1 ball, 7.4ms
# image 502/2219 /kaggle/working/test/game2_Clip2_0140.jpg: 384x640 1 ball, 7.5ms
# image 503/2219 /kaggle/working/test/game2_Clip2_0141.jpg: 384x640 1 ball, 7.5ms
# image 504/2219 /kaggle/working/test/game2_Clip2_0142.jpg: 384x640 1 ball, 7.5ms
# image 505/2219 /kaggle/working/test/game2_Clip2_0143.jpg: 384x640 1 ball, 7.5ms
# image 506/2219 /kaggle/working/test/game2_Clip2_0144.jpg: 384x640 1 ball, 7.5ms
# image 507/2219 /kaggle/working/test/game2_Clip2_0145.jpg: 384x640 1 ball, 7.5ms
# image 508/2219 /kaggle/working/test/game2_Clip2_0146.jpg: 384x640 1 ball, 7.5ms
# image 509/2219 /kaggle/working/test/game2_Clip2_0147.jpg: 384x640 1 ball, 7.5ms
# image 510/2219 /kaggle/working/test/game2_Clip2_0148.jpg: 384x640 1 ball, 7.5ms
# image 511/2219 /kaggle/working/test/game2_Clip2_0149.jpg: 384x640 1 ball, 7.5ms
# image 512/2219 /kaggle/working/test/game2_Clip2_0150.jpg: 384x640 1 ball, 7.5ms
# image 513/2219 /kaggle/working/test/game2_Clip2_0151.jpg: 384x640 1 ball, 7.5ms
# image 514/2219 /kaggle/working/test/game2_Clip2_0152.jpg: 384x640 1 ball, 7.5ms
# image 515/2219 /kaggle/working/test/game2_Clip2_0153.jpg: 384x640 1 ball, 7.5ms
# image 516/2219 /kaggle/working/test/game2_Clip2_0154.jpg: 384x640 1 ball, 7.5ms
# image 517/2219 /kaggle/working/test/game2_Clip2_0155.jpg: 384x640 1 ball, 7.5ms
# image 518/2219 /kaggle/working/test/game2_Clip2_0156.jpg: 384x640 1 ball, 7.5ms
# image 519/2219 /kaggle/working/test/game2_Clip2_0157.jpg: 384x640 1 ball, 7.5ms
# image 520/2219 /kaggle/working/test/game2_Clip2_0158.jpg: 384x640 1 ball, 7.5ms
# image 521/2219 /kaggle/working/test/game2_Clip2_0159.jpg: 384x640 2 balls, 7.5ms
# image 522/2219 /kaggle/working/test/game2_Clip2_0160.jpg: 384x640 (no detections), 7.5ms
# image 523/2219 /kaggle/working/test/game2_Clip2_0161.jpg: 384x640 1 ball, 7.5ms
# image 524/2219 /kaggle/working/test/game2_Clip2_0162.jpg: 384x640 1 ball, 7.5ms
# image 525/2219 /kaggle/working/test/game2_Clip2_0163.jpg: 384x640 1 ball, 7.5ms
# image 526/2219 /kaggle/working/test/game2_Clip2_0164.jpg: 384x640 1 ball, 7.5ms
# image 527/2219 /kaggle/working/test/game2_Clip2_0165.jpg: 384x640 1 ball, 7.5ms
# image 528/2219 /kaggle/working/test/game2_Clip2_0166.jpg: 384x640 1 ball, 7.5ms
# image 529/2219 /kaggle/working/test/game2_Clip2_0167.jpg: 384x640 1 ball, 7.5ms
# image 530/2219 /kaggle/working/test/game2_Clip2_0168.jpg: 384x640 1 ball, 7.5ms
# image 531/2219 /kaggle/working/test/game2_Clip2_0169.jpg: 384x640 1 ball, 7.5ms
# image 532/2219 /kaggle/working/test/game2_Clip2_0170.jpg: 384x640 1 ball, 7.5ms
# image 533/2219 /kaggle/working/test/game2_Clip2_0171.jpg: 384x640 1 ball, 7.5ms
# image 534/2219 /kaggle/working/test/game2_Clip2_0172.jpg: 384x640 1 ball, 7.5ms
# image 535/2219 /kaggle/working/test/game2_Clip2_0173.jpg: 384x640 1 ball, 7.5ms
# image 536/2219 /kaggle/working/test/game2_Clip2_0174.jpg: 384x640 (no detections), 7.5ms
# image 537/2219 /kaggle/working/test/game2_Clip2_0175.jpg: 384x640 1 ball, 7.5ms
# image 538/2219 /kaggle/working/test/game2_Clip2_0176.jpg: 384x640 1 ball, 7.5ms
# image 539/2219 /kaggle/working/test/game2_Clip2_0177.jpg: 384x640 (no detections), 7.5ms
# image 540/2219 /kaggle/working/test/game2_Clip2_0178.jpg: 384x640 (no detections), 7.5ms
# image 541/2219 /kaggle/working/test/game2_Clip2_0179.jpg: 384x640 (no detections), 7.5ms
# image 542/2219 /kaggle/working/test/game2_Clip2_0180.jpg: 384x640 (no detections), 7.5ms
# image 543/2219 /kaggle/working/test/game2_Clip2_0181.jpg: 384x640 1 ball, 7.5ms
# image 544/2219 /kaggle/working/test/game2_Clip2_0182.jpg: 384x640 1 ball, 7.5ms
# image 545/2219 /kaggle/working/test/game2_Clip2_0183.jpg: 384x640 1 ball, 7.5ms
# image 546/2219 /kaggle/working/test/game2_Clip2_0184.jpg: 384x640 1 ball, 7.5ms
# image 547/2219 /kaggle/working/test/game2_Clip2_0185.jpg: 384x640 1 ball, 7.5ms
# image 548/2219 /kaggle/working/test/game2_Clip2_0186.jpg: 384x640 1 ball, 7.5ms
# image 549/2219 /kaggle/working/test/game2_Clip2_0187.jpg: 384x640 1 ball, 7.5ms
# image 550/2219 /kaggle/working/test/game2_Clip2_0188.jpg: 384x640 1 ball, 7.5ms
# image 551/2219 /kaggle/working/test/game2_Clip2_0189.jpg: 384x640 1 ball, 7.5ms
# image 552/2219 /kaggle/working/test/game2_Clip2_0190.jpg: 384x640 1 ball, 7.5ms
# image 553/2219 /kaggle/working/test/game2_Clip2_0191.jpg: 384x640 1 ball, 7.5ms
# image 554/2219 /kaggle/working/test/game2_Clip2_0192.jpg: 384x640 1 ball, 7.5ms
# image 555/2219 /kaggle/working/test/game2_Clip2_0193.jpg: 384x640 1 ball, 7.5ms
# image 556/2219 /kaggle/working/test/game2_Clip2_0194.jpg: 384x640 (no detections), 7.5ms
# image 557/2219 /kaggle/working/test/game2_Clip2_0195.jpg: 384x640 1 ball, 7.5ms
# image 558/2219 /kaggle/working/test/game2_Clip2_0196.jpg: 384x640 (no detections), 7.5ms
# image 559/2219 /kaggle/working/test/game2_Clip2_0197.jpg: 384x640 (no detections), 7.5ms
# image 560/2219 /kaggle/working/test/game2_Clip2_0198.jpg: 384x640 (no detections), 7.5ms
# image 561/2219 /kaggle/working/test/game2_Clip3_0000.jpg: 384x640 1 ball, 7.5ms
# image 562/2219 /kaggle/working/test/game2_Clip3_0001.jpg: 384x640 1 ball, 7.5ms
# image 563/2219 /kaggle/working/test/game2_Clip3_0002.jpg: 384x640 1 ball, 7.5ms
# image 564/2219 /kaggle/working/test/game2_Clip3_0003.jpg: 384x640 1 ball, 7.5ms
# image 565/2219 /kaggle/working/test/game2_Clip3_0004.jpg: 384x640 1 ball, 7.5ms
# image 566/2219 /kaggle/working/test/game2_Clip3_0005.jpg: 384x640 1 ball, 7.5ms
# image 567/2219 /kaggle/working/test/game2_Clip3_0006.jpg: 384x640 1 ball, 7.5ms
# image 568/2219 /kaggle/working/test/game2_Clip3_0007.jpg: 384x640 1 ball, 7.5ms
# image 569/2219 /kaggle/working/test/game2_Clip3_0008.jpg: 384x640 2 balls, 7.5ms
# image 570/2219 /kaggle/working/test/game2_Clip3_0009.jpg: 384x640 1 ball, 7.5ms
# image 571/2219 /kaggle/working/test/game2_Clip3_0010.jpg: 384x640 1 ball, 7.5ms
# image 572/2219 /kaggle/working/test/game2_Clip3_0011.jpg: 384x640 1 ball, 7.5ms
# image 573/2219 /kaggle/working/test/game2_Clip3_0012.jpg: 384x640 (no detections), 7.5ms
# image 574/2219 /kaggle/working/test/game2_Clip3_0013.jpg: 384x640 (no detections), 7.5ms
# image 575/2219 /kaggle/working/test/game2_Clip3_0014.jpg: 384x640 1 ball, 7.5ms
# image 576/2219 /kaggle/working/test/game2_Clip3_0015.jpg: 384x640 1 ball, 7.5ms
# image 577/2219 /kaggle/working/test/game2_Clip3_0016.jpg: 384x640 1 ball, 7.5ms
# image 578/2219 /kaggle/working/test/game2_Clip3_0017.jpg: 384x640 1 ball, 7.5ms
# ...
# image 2026/2219 /kaggle/working/test/game2_Clip8_0451.jpg: 384x640 1 ball, 7.5ms
# image 2027/2219 /kaggle/working/test/game2_Clip8_0452.jpg: 384x640 1 ball, 7.5ms
# image 2028/2219 /kaggle/working/test/game2_Clip8_0453.jpg: 384x640 1 ball, 7.5ms
# image 2029/2219 /kaggle/working/test/game2_Clip8_0454.jpg: 384x640 1 ball, 7.5ms
# image 2030/2219 /kaggle/working/test/game2_Clip8_0455.jpg: 384x640 1 ball, 7.5ms
# image 2031/2219 /kaggle/working/test/game2_Clip8_0456.jpg: 384x640 1 ball, 7.5ms
# image 2032/2219 /kaggle/working/test/game2_Clip8_0457.jpg: 384x640 1 ball, 7.5ms
# image 2033/2219 /kaggle/working/test/game2_Clip8_0458.jpg: 384x640 1 ball, 7.5ms
# image 2034/2219 /kaggle/working/test/game2_Clip8_0459.jpg: 384x640 1 ball, 7.5ms
# image 2035/2219 /kaggle/working/test/game2_Clip8_0460.jpg: 384x640 1 ball, 7.5ms
# image 2036/2219 /kaggle/working/test/game2_Clip8_0461.jpg: 384x640 1 ball, 7.5ms
# image 2037/2219 /kaggle/working/test/game2_Clip8_0462.jpg: 384x640 1 ball, 7.5ms
# image 2038/2219 /kaggle/working/test/game2_Clip8_0463.jpg: 384x640 1 ball, 7.5ms
# image 2039/2219 /kaggle/working/test/game2_Clip8_0464.jpg: 384x640 (no detections), 7.5ms
# image 2040/2219 /kaggle/working/test/game2_Clip8_0465.jpg: 384x640 1 ball, 7.5ms
# image 2041/2219 /kaggle/working/test/game2_Clip8_0466.jpg: 384x640 1 ball, 7.5ms
# image 2042/2219 /kaggle/working/test/game2_Clip8_0467.jpg: 384x640 1 ball, 7.5ms
# image 2043/2219 /kaggle/working/test/game2_Clip8_0468.jpg: 384x640 1 ball, 7.5ms
# image 2044/2219 /kaggle/working/test/game2_Clip8_0469.jpg: 384x640 1 ball, 7.5ms
# image 2045/2219 /kaggle/working/test/game2_Clip8_0470.jpg: 384x640 (no detections), 7.5ms
# image 2046/2219 /kaggle/working/test/game2_Clip8_0471.jpg: 384x640 1 ball, 7.5ms
# image 2047/2219 /kaggle/working/test/game2_Clip8_0472.jpg: 384x640 1 ball, 7.5ms
# image 2048/2219 /kaggle/working/test/game2_Clip8_0473.jpg: 384x640 1 ball, 7.5ms
# image 2049/2219 /kaggle/working/test/game2_Clip8_0474.jpg: 384x640 1 ball, 7.5ms
# image 2050/2219 /kaggle/working/test/game2_Clip8_0475.jpg: 384x640 1 ball, 7.5ms
# image 2051/2219 /kaggle/working/test/game2_Clip8_0476.jpg: 384x640 1 ball, 7.5ms
# image 2052/2219 /kaggle/working/test/game2_Clip8_0477.jpg: 384x640 1 ball, 7.5ms
# image 2053/2219 /kaggle/working/test/game2_Clip8_0478.jpg: 384x640 1 ball, 7.4ms
# image 2054/2219 /kaggle/working/test/game2_Clip8_0479.jpg: 384x640 1 ball, 7.5ms
# image 2055/2219 /kaggle/working/test/game2_Clip8_0480.jpg: 384x640 1 ball, 7.5ms
# image 2056/2219 /kaggle/working/test/game2_Clip8_0481.jpg: 384x640 1 ball, 7.5ms
# image 2057/2219 /kaggle/working/test/game2_Clip8_0482.jpg: 384x640 1 ball, 7.5ms
# image 2058/2219 /kaggle/working/test/game2_Clip8_0483.jpg: 384x640 1 ball, 7.5ms
# image 2059/2219 /kaggle/working/test/game2_Clip8_0484.jpg: 384x640 1 ball, 7.5ms
# image 2060/2219 /kaggle/working/test/game2_Clip8_0485.jpg: 384x640 (no detections), 7.5ms
# image 2061/2219 /kaggle/working/test/game2_Clip8_0486.jpg: 384x640 1 ball, 7.5ms
# image 2062/2219 /kaggle/working/test/game2_Clip8_0487.jpg: 384x640 1 ball, 7.5ms
# image 2063/2219 /kaggle/working/test/game2_Clip8_0488.jpg: 384x640 1 ball, 7.5ms
# image 2064/2219 /kaggle/working/test/game2_Clip8_0489.jpg: 384x640 1 ball, 7.5ms
# image 2065/2219 /kaggle/working/test/game2_Clip8_0490.jpg: 384x640 1 ball, 7.5ms
# image 2066/2219 /kaggle/working/test/game2_Clip8_0491.jpg: 384x640 1 ball, 7.5ms
# image 2067/2219 /kaggle/working/test/game2_Clip8_0492.jpg: 384x640 1 ball, 7.5ms
# image 2068/2219 /kaggle/working/test/game2_Clip8_0493.jpg: 384x640 1 ball, 7.5ms
# image 2069/2219 /kaggle/working/test/game2_Clip8_0494.jpg: 384x640 1 ball, 7.5ms
# image 2070/2219 /kaggle/working/test/game2_Clip8_0495.jpg: 384x640 1 ball, 7.5ms
# image 2071/2219 /kaggle/working/test/game2_Clip8_0496.jpg: 384x640 1 ball, 7.5ms
# image 2072/2219 /kaggle/working/test/game2_Clip8_0497.jpg: 384x640 1 ball, 7.5ms
# image 2073/2219 /kaggle/working/test/game2_Clip8_0498.jpg: 384x640 1 ball, 7.5ms
# image 2074/2219 /kaggle/working/test/game2_Clip8_0499.jpg: 384x640 1 ball, 7.5ms
# image 2075/2219 /kaggle/working/test/game2_Clip8_0500.jpg: 384x640 1 ball, 7.5ms
# image 2076/2219 /kaggle/working/test/game2_Clip8_0501.jpg: 384x640 1 ball, 7.5ms
# image 2077/2219 /kaggle/working/test/game2_Clip8_0502.jpg: 384x640 1 ball, 7.5ms
# image 2078/2219 /kaggle/working/test/game2_Clip8_0503.jpg: 384x640 1 ball, 7.5ms
# image 2079/2219 /kaggle/working/test/game2_Clip8_0504.jpg: 384x640 1 ball, 7.5ms
# image 2080/2219 /kaggle/working/test/game2_Clip8_0505.jpg: 384x640 1 ball, 7.5ms
# image 2081/2219 /kaggle/working/test/game2_Clip8_0506.jpg: 384x640 1 ball, 7.5ms
# image 2082/2219 /kaggle/working/test/game2_Clip8_0507.jpg: 384x640 1 ball, 7.5ms
# image 2083/2219 /kaggle/working/test/game2_Clip8_0508.jpg: 384x640 1 ball, 7.5ms
# image 2084/2219 /kaggle/working/test/game2_Clip8_0509.jpg: 384x640 1 ball, 7.5ms
# image 2085/2219 /kaggle/working/test/game2_Clip8_0510.jpg: 384x640 2 balls, 7.5ms
# image 2086/2219 /kaggle/working/test/game2_Clip8_0511.jpg: 384x640 1 ball, 7.5ms
# image 2087/2219 /kaggle/working/test/game2_Clip8_0512.jpg: 384x640 1 ball, 7.5ms
# image 2088/2219 /kaggle/working/test/game2_Clip8_0513.jpg: 384x640 1 ball, 7.5ms
# image 2089/2219 /kaggle/working/test/game2_Clip8_0514.jpg: 384x640 1 ball, 7.5ms
# image 2090/2219 /kaggle/working/test/game2_Clip8_0515.jpg: 384x640 2 balls, 7.5ms
# image 2091/2219 /kaggle/working/test/game2_Clip8_0516.jpg: 384x640 1 ball, 7.5ms
# image 2092/2219 /kaggle/working/test/game2_Clip8_0517.jpg: 384x640 1 ball, 7.5ms
# image 2093/2219 /kaggle/working/test/game2_Clip8_0518.jpg: 384x640 1 ball, 7.5ms
# image 2094/2219 /kaggle/working/test/game2_Clip8_0519.jpg: 384x640 1 ball, 7.5ms
# image 2095/2219 /kaggle/working/test/game2_Clip8_0520.jpg: 384x640 1 ball, 7.5ms
# image 2096/2219 /kaggle/working/test/game2_Clip8_0521.jpg: 384x640 1 ball, 7.5ms
# image 2097/2219 /kaggle/working/test/game2_Clip8_0522.jpg: 384x640 1 ball, 7.5ms
# image 2098/2219 /kaggle/working/test/game2_Clip8_0523.jpg: 384x640 1 ball, 7.5ms
# image 2099/2219 /kaggle/working/test/game2_Clip8_0524.jpg: 384x640 1 ball, 7.5ms
# image 2100/2219 /kaggle/working/test/game2_Clip8_0525.jpg: 384x640 1 ball, 7.5ms
# image 2101/2219 /kaggle/working/test/game2_Clip8_0526.jpg: 384x640 1 ball, 7.5ms
# image 2102/2219 /kaggle/working/test/game2_Clip8_0527.jpg: 384x640 1 ball, 7.5ms
# image 2103/2219 /kaggle/working/test/game2_Clip8_0528.jpg: 384x640 1 ball, 7.5ms
# image 2104/2219 /kaggle/working/test/game2_Clip8_0529.jpg: 384x640 1 ball, 7.5ms
# image 2105/2219 /kaggle/working/test/game2_Clip8_0530.jpg: 384x640 1 ball, 7.5ms
# image 2106/2219 /kaggle/working/test/game2_Clip8_0531.jpg: 384x640 2 balls, 7.5ms
# image 2107/2219 /kaggle/working/test/game2_Clip8_0532.jpg: 384x640 1 ball, 7.5ms
# image 2108/2219 /kaggle/working/test/game2_Clip8_0533.jpg: 384x640 2 balls, 7.5ms
# image 2109/2219 /kaggle/working/test/game2_Clip8_0534.jpg: 384x640 2 balls, 7.5ms
# image 2110/2219 /kaggle/working/test/game2_Clip8_0535.jpg: 384x640 1 ball, 7.5ms
# image 2111/2219 /kaggle/working/test/game2_Clip8_0536.jpg: 384x640 1 ball, 7.5ms
# image 2112/2219 /kaggle/working/test/game2_Clip8_0537.jpg: 384x640 1 ball, 7.5ms
# image 2113/2219 /kaggle/working/test/game2_Clip8_0538.jpg: 384x640 1 ball, 7.5ms
# image 2114/2219 /kaggle/working/test/game2_Clip8_0539.jpg: 384x640 1 ball, 7.5ms
# image 2115/2219 /kaggle/working/test/game2_Clip8_0540.jpg: 384x640 1 ball, 7.5ms
# image 2116/2219 /kaggle/working/test/game2_Clip8_0541.jpg: 384x640 1 ball, 7.5ms
# image 2117/2219 /kaggle/working/test/game2_Clip8_0542.jpg: 384x640 1 ball, 7.5ms
# image 2118/2219 /kaggle/working/test/game2_Clip8_0543.jpg: 384x640 1 ball, 7.5ms
# image 2119/2219 /kaggle/working/test/game2_Clip8_0544.jpg: 384x640 1 ball, 7.5ms
# image 2120/2219 /kaggle/working/test/game2_Clip8_0545.jpg: 384x640 1 ball, 7.5ms
# image 2121/2219 /kaggle/working/test/game2_Clip8_0546.jpg: 384x640 1 ball, 7.5ms
# image 2122/2219 /kaggle/working/test/game2_Clip8_0547.jpg: 384x640 1 ball, 7.5ms
# image 2123/2219 /kaggle/working/test/game2_Clip8_0548.jpg: 384x640 1 ball, 7.4ms
# image 2124/2219 /kaggle/working/test/game2_Clip8_0549.jpg: 384x640 1 ball, 7.5ms
# image 2125/2219 /kaggle/working/test/game2_Clip8_0550.jpg: 384x640 1 ball, 7.5ms
# image 2126/2219 /kaggle/working/test/game2_Clip8_0551.jpg: 384x640 2 balls, 7.5ms
# image 2127/2219 /kaggle/working/test/game2_Clip8_0552.jpg: 384x640 1 ball, 7.5ms
# image 2128/2219 /kaggle/working/test/game2_Clip8_0553.jpg: 384x640 1 ball, 7.5ms
# image 2129/2219 /kaggle/working/test/game2_Clip8_0554.jpg: 384x640 1 ball, 7.5ms
# image 2130/2219 /kaggle/working/test/game2_Clip8_0555.jpg: 384x640 1 ball, 7.5ms
# image 2131/2219 /kaggle/working/test/game2_Clip8_0556.jpg: 384x640 1 ball, 7.5ms
# image 2132/2219 /kaggle/working/test/game2_Clip8_0557.jpg: 384x640 1 ball, 7.5ms
# image 2133/2219 /kaggle/working/test/game2_Clip8_0558.jpg: 384x640 1 ball, 7.5ms
# image 2134/2219 /kaggle/working/test/game2_Clip8_0559.jpg: 384x640 1 ball, 7.5ms
# image 2135/2219 /kaggle/working/test/game2_Clip8_0560.jpg: 384x640 1 ball, 7.5ms
# image 2136/2219 /kaggle/working/test/game2_Clip8_0561.jpg: 384x640 (no detections), 7.5ms
# image 2137/2219 /kaggle/working/test/game2_Clip8_0562.jpg: 384x640 1 ball, 7.5ms
# image 2138/2219 /kaggle/working/test/game2_Clip8_0563.jpg: 384x640 1 ball, 7.4ms
# image 2139/2219 /kaggle/working/test/game2_Clip8_0564.jpg: 384x640 1 ball, 7.5ms
# image 2140/2219 /kaggle/working/test/game2_Clip8_0565.jpg: 384x640 1 ball, 7.5ms
# image 2141/2219 /kaggle/working/test/game2_Clip8_0566.jpg: 384x640 1 ball, 7.5ms
# image 2142/2219 /kaggle/working/test/game2_Clip8_0567.jpg: 384x640 1 ball, 7.5ms
# image 2143/2219 /kaggle/working/test/game2_Clip8_0568.jpg: 384x640 1 ball, 7.5ms
# image 2144/2219 /kaggle/working/test/game2_Clip8_0569.jpg: 384x640 1 ball, 7.5ms
# image 2145/2219 /kaggle/working/test/game2_Clip8_0570.jpg: 384x640 1 ball, 7.5ms
# image 2146/2219 /kaggle/working/test/game2_Clip8_0571.jpg: 384x640 1 ball, 7.5ms
# image 2147/2219 /kaggle/working/test/game2_Clip8_0572.jpg: 384x640 1 ball, 7.5ms
# image 2148/2219 /kaggle/working/test/game2_Clip8_0573.jpg: 384x640 1 ball, 7.5ms
# image 2149/2219 /kaggle/working/test/game2_Clip8_0574.jpg: 384x640 1 ball, 7.5ms
# image 2150/2219 /kaggle/working/test/game2_Clip8_0575.jpg: 384x640 1 ball, 7.5ms
# image 2151/2219 /kaggle/working/test/game2_Clip8_0576.jpg: 384x640 1 ball, 7.5ms
# image 2152/2219 /kaggle/working/test/game2_Clip8_0577.jpg: 384x640 (no detections), 7.5ms
# image 2153/2219 /kaggle/working/test/game2_Clip8_0578.jpg: 384x640 1 ball, 7.5ms
# image 2154/2219 /kaggle/working/test/game2_Clip8_0579.jpg: 384x640 1 ball, 7.5ms
# image 2155/2219 /kaggle/working/test/game2_Clip8_0580.jpg: 384x640 1 ball, 7.5ms
# image 2156/2219 /kaggle/working/test/game2_Clip8_0581.jpg: 384x640 1 ball, 7.5ms
# image 2157/2219 /kaggle/working/test/game2_Clip8_0582.jpg: 384x640 (no detections), 7.5ms
# image 2158/2219 /kaggle/working/test/game2_Clip8_0583.jpg: 384x640 (no detections), 7.5ms
# image 2159/2219 /kaggle/working/test/game2_Clip8_0584.jpg: 384x640 1 ball, 7.5ms
# image 2160/2219 /kaggle/working/test/game2_Clip8_0585.jpg: 384x640 1 ball, 7.5ms
# image 2161/2219 /kaggle/working/test/game2_Clip8_0586.jpg: 384x640 1 ball, 7.5ms
# image 2162/2219 /kaggle/working/test/game2_Clip8_0587.jpg: 384x640 1 ball, 7.5ms
# image 2163/2219 /kaggle/working/test/game2_Clip8_0588.jpg: 384x640 1 ball, 7.5ms
# image 2164/2219 /kaggle/working/test/game2_Clip8_0589.jpg: 384x640 (no detections), 7.5ms
# image 2165/2219 /kaggle/working/test/game2_Clip8_0590.jpg: 384x640 2 balls, 7.4ms
# image 2166/2219 /kaggle/working/test/game2_Clip8_0591.jpg: 384x640 2 balls, 7.5ms
# image 2167/2219 /kaggle/working/test/game2_Clip8_0592.jpg: 384x640 1 ball, 7.5ms
# image 2168/2219 /kaggle/working/test/game2_Clip8_0593.jpg: 384x640 1 ball, 7.5ms
# image 2169/2219 /kaggle/working/test/game2_Clip8_0594.jpg: 384x640 1 ball, 7.5ms
# image 2170/2219 /kaggle/working/test/game2_Clip8_0595.jpg: 384x640 1 ball, 7.5ms
# image 2171/2219 /kaggle/working/test/game2_Clip8_0596.jpg: 384x640 1 ball, 7.5ms
# image 2172/2219 /kaggle/working/test/game2_Clip8_0597.jpg: 384x640 1 ball, 7.5ms
# image 2173/2219 /kaggle/working/test/game2_Clip8_0598.jpg: 384x640 1 ball, 7.5ms
# image 2174/2219 /kaggle/working/test/game2_Clip8_0599.jpg: 384x640 1 ball, 7.5ms
# image 2175/2219 /kaggle/working/test/game2_Clip8_0600.jpg: 384x640 1 ball, 7.5ms
# image 2176/2219 /kaggle/working/test/game2_Clip8_0601.jpg: 384x640 1 ball, 7.5ms
# image 2177/2219 /kaggle/working/test/game2_Clip8_0602.jpg: 384x640 1 ball, 7.5ms
# image 2178/2219 /kaggle/working/test/game2_Clip8_0603.jpg: 384x640 1 ball, 7.5ms
# image 2179/2219 /kaggle/working/test/game2_Clip8_0604.jpg: 384x640 1 ball, 7.5ms
# image 2180/2219 /kaggle/working/test/game2_Clip8_0605.jpg: 384x640 1 ball, 7.5ms
# image 2181/2219 /kaggle/working/test/game2_Clip8_0606.jpg: 384x640 1 ball, 7.5ms
# image 2182/2219 /kaggle/working/test/game2_Clip8_0607.jpg: 384x640 1 ball, 7.4ms
# image 2183/2219 /kaggle/working/test/game2_Clip8_0608.jpg: 384x640 1 ball, 7.5ms
# image 2184/2219 /kaggle/working/test/game2_Clip8_0609.jpg: 384x640 1 ball, 7.5ms
# image 2185/2219 /kaggle/working/test/game2_Clip8_0610.jpg: 384x640 1 ball, 7.5ms
# image 2186/2219 /kaggle/working/test/game2_Clip8_0611.jpg: 384x640 (no detections), 7.5ms
# image 2187/2219 /kaggle/working/test/game2_Clip8_0612.jpg: 384x640 (no detections), 7.5ms
# image 2188/2219 /kaggle/working/test/game2_Clip8_0613.jpg: 384x640 1 ball, 7.5ms
# image 2189/2219 /kaggle/working/test/game2_Clip8_0614.jpg: 384x640 1 ball, 7.5ms
# image 2190/2219 /kaggle/working/test/game2_Clip8_0615.jpg: 384x640 1 ball, 7.5ms
# image 2191/2219 /kaggle/working/test/game2_Clip8_0616.jpg: 384x640 1 ball, 7.5ms
# image 2192/2219 /kaggle/working/test/game2_Clip8_0617.jpg: 384x640 1 ball, 7.5ms
# image 2193/2219 /kaggle/working/test/game2_Clip8_0618.jpg: 384x640 1 ball, 7.5ms
# image 2194/2219 /kaggle/working/test/game2_Clip8_0619.jpg: 384x640 1 ball, 7.5ms
# image 2195/2219 /kaggle/working/test/game2_Clip8_0620.jpg: 384x640 2 balls, 7.4ms
# image 2196/2219 /kaggle/working/test/game2_Clip8_0621.jpg: 384x640 1 ball, 7.5ms
# image 2197/2219 /kaggle/working/test/game2_Clip8_0622.jpg: 384x640 2 balls, 7.5ms
# image 2198/2219 /kaggle/working/test/game2_Clip8_0623.jpg: 384x640 (no detections), 7.5ms
# image 2199/2219 /kaggle/working/test/game2_Clip8_0624.jpg: 384x640 (no detections), 7.5ms
# image 2200/2219 /kaggle/working/test/game2_Clip8_0625.jpg: 384x640 (no detections), 7.5ms
# image 2201/2219 /kaggle/working/test/game2_Clip8_0626.jpg: 384x640 1 ball, 7.5ms
# image 2202/2219 /kaggle/working/test/game2_Clip8_0627.jpg: 384x640 1 ball, 7.5ms
# image 2203/2219 /kaggle/working/test/game2_Clip8_0628.jpg: 384x640 1 ball, 7.5ms
# image 2204/2219 /kaggle/working/test/game2_Clip8_0629.jpg: 384x640 1 ball, 7.5ms
# image 2205/2219 /kaggle/working/test/game2_Clip8_0630.jpg: 384x640 1 ball, 7.5ms
# image 2206/2219 /kaggle/working/test/game2_Clip8_0631.jpg: 384x640 (no detections), 7.5ms
# image 2207/2219 /kaggle/working/test/game2_Clip8_0632.jpg: 384x640 1 ball, 7.5ms
# image 2208/2219 /kaggle/working/test/game2_Clip8_0633.jpg: 384x640 1 ball, 7.5ms
# image 2209/2219 /kaggle/working/test/game2_Clip8_0634.jpg: 384x640 1 ball, 7.5ms
# image 2210/2219 /kaggle/working/test/game2_Clip8_0635.jpg: 384x640 (no detections), 7.5ms
# image 2211/2219 /kaggle/working/test/game2_Clip8_0636.jpg: 384x640 1 ball, 7.5ms
# image 2212/2219 /kaggle/working/test/game2_Clip8_0637.jpg: 384x640 1 ball, 7.5ms
# image 2213/2219 /kaggle/working/test/game2_Clip8_0638.jpg: 384x640 1 ball, 7.5ms
# image 2214/2219 /kaggle/working/test/game2_Clip8_0639.jpg: 384x640 1 ball, 7.5ms
# image 2215/2219 /kaggle/working/test/game2_Clip8_0640.jpg: 384x640 1 ball, 7.5ms
# image 2216/2219 /kaggle/working/test/game2_Clip8_0641.jpg: 384x640 1 ball, 7.5ms
# image 2217/2219 /kaggle/working/test/game2_Clip8_0642.jpg: 384x640 1 ball, 7.5ms
# image 2218/2219 /kaggle/working/test/game2_Clip8_0643.jpg: 384x640 1 ball, 7.5ms
# image 2219/2219 /kaggle/working/test/game2_Clip8_0644.jpg: 384x640 1 ball, 7.5ms
# Speed: 0.4ms pre-process, 7.5ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# %cd runs/detect/exp2
# Out:
# /kaggle/working/yolov5/runs/detect/exp2

# %%
# %cd /kaggle/working/yolov5
# Out:
# /kaggle/working/yolov5

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /kaggle/input/sampletennisvideo/sample1.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/kaggle/input/sampletennisvideo/sample1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: Ultralytics requirement ['Pillow>=10.0.1'] not found, attempting AutoUpdate...
# Requirement already satisfied: Pillow>=10.0.1 in /opt/conda/lib/python3.10/site-packages (10.1.0)
#
# requirements: AutoUpdate success ✅ 11.0s, installed 1 package: ['Pillow>=10.0.1']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 57.2ms
# video 1/1 (2/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.6ms
# video 1/1 (3/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.5ms
# video 1/1 (4/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.5ms
# video 1/1 (5/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.5ms
# video 1/1 (6/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.5ms
# video 1/1 (7/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.5ms
# video 1/1 (8/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.5ms
# video 1/1 (9/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.6ms
# video 1/1 (10/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.5ms
# video 1/1 (11/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.6ms
# video 1/1 (12/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.5ms
# video 1/1 (13/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.2ms
# video 1/1 (14/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.2ms
# video 1/1 (15/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.2ms
# video 1/1 (16/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.2ms
# video 1/1 (17/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.3ms
# video 1/1 (18/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.2ms
# video 1/1 (19/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.3ms
# video 1/1 (20/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.3ms
# video 1/1 (21/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.2ms
# video 1/1 (22/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.2ms
# video 1/1 (23/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.2ms
# video 1/1 (24/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (25/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (26/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (27/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (28/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.3ms
# video 1/1 (29/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (30/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (31/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (32/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (33/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (34/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (35/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (36/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (37/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (38/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (39/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (40/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (41/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (42/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (43/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (44/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (45/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (46/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (47/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (48/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (49/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (50/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (51/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (52/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (53/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (54/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (55/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (56/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (57/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.8ms
# video 1/1 (58/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (59/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (60/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (61/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (62/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (63/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (64/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (65/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (66/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (67/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (68/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (69/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (70/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (71/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (72/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (73/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (74/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (75/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (76/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (77/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (78/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.6ms
# video 1/1 (79/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (80/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (81/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (82/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (83/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (84/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (85/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (86/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (87/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (88/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.0ms
# video 1/1 (89/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (90/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (91/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.0ms
# video 1/1 (92/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (93/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.4ms
# video 1/1 (94/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (95/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (96/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (97/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (98/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (99/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (100/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.1ms
# video 1/1 (101/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (102/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (103/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (104/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (105/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (106/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (107/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (108/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (109/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (110/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (111/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (112/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (113/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (114/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (115/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (116/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.8ms
# video 1/1 (117/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (118/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (119/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (120/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.5ms
# video 1/1 (121/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (122/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (123/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.3ms
# video 1/1 (124/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (125/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (126/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (127/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (128/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (129/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (130/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.3ms
# video 1/1 (131/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (132/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.3ms
# video 1/1 (133/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (134/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (135/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (136/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (137/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (138/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (139/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (140/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (141/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (142/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (143/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (144/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (145/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (146/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (147/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (148/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.1ms
# video 1/1 (149/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (150/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (151/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (152/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (153/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (154/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (155/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (156/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 7.4ms
# video 1/1 (157/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (158/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (159/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (160/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (161/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (162/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.9ms
# video 1/1 (163/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (164/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (165/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (166/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (167/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (168/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.9ms
# video 1/1 (169/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.6ms
# video 1/1 (170/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 10.7ms
# video 1/1 (171/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 10.6ms
# video 1/1 (172/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 9.4ms
# video 1/1 (173/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 10.2ms
# video 1/1 (174/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 8.1ms
# video 1/1 (175/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 7.3ms
# video 1/1 (176/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.4ms
# video 1/1 (177/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (178/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.9ms
# video 1/1 (179/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.4ms
# video 1/1 (180/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (181/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.8ms
# video 1/1 (182/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.5ms
# video 1/1 (183/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.8ms
# video 1/1 (184/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (185/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (186/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 8.7ms
# video 1/1 (187/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (188/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 8.0ms
# video 1/1 (189/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (190/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (191/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 9.1ms
# video 1/1 (192/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 8.3ms
# video 1/1 (193/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.2ms
# video 1/1 (194/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.7ms
# video 1/1 (195/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (196/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (197/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.6ms
# video 1/1 (198/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (199/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (200/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (201/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (202/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (203/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (204/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (205/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (206/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (207/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (208/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (209/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.2ms
# video 1/1 (210/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (211/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (212/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (213/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (214/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (215/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (216/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (217/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (218/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (219/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (220/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (221/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (222/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (223/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (224/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (225/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (226/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (227/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (228/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (229/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (230/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (231/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.8ms
# video 1/1 (232/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.5ms
# video 1/1 (233/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.8ms
# video 1/1 (234/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (235/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (236/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (237/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (238/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (239/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (240/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (241/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.5ms
# video 1/1 (242/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.8ms
# video 1/1 (243/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (244/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.5ms
# video 1/1 (245/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.8ms
# video 1/1 (246/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (247/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.3ms
# video 1/1 (248/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (249/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (250/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.0ms
# video 1/1 (251/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (252/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (253/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.5ms
# video 1/1 (254/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.8ms
# video 1/1 (255/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (256/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.5ms
# video 1/1 (257/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 5.8ms
# video 1/1 (258/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (259/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.5ms
# video 1/1 (260/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (261/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (262/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (263/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (264/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (265/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.3ms
# video 1/1 (266/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (267/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.2ms
# video 1/1 (268/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.9ms
# video 1/1 (269/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.3ms
# video 1/1 (270/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (271/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.5ms
# video 1/1 (272/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (273/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (274/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.9ms
# video 1/1 (275/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (276/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (277/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.1ms
# video 1/1 (278/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (279/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (280/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (281/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (282/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (283/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (284/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (285/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (286/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (287/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (288/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (289/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (290/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.7ms
# video 1/1 (291/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (292/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (293/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (294/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (295/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (296/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.1ms
# video 1/1 (297/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (298/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (299/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.6ms
# video 1/1 (300/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.0ms
# video 1/1 (301/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 5.8ms
# video 1/1 (302/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.7ms
# video 1/1 (303/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.6ms
# video 1/1 (304/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (305/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.5ms
# video 1/1 (306/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (307/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.0ms
# video 1/1 (308/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.6ms
# video 1/1 (309/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (310/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (311/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.5ms
# video 1/1 (312/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.8ms
# video 1/1 (313/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.8ms
# video 1/1 (314/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (315/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (316/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (317/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (318/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (319/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.8ms
# video 1/1 (320/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (321/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.4ms
# video 1/1 (322/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.8ms
# video 1/1 (323/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (324/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (325/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.8ms
# video 1/1 (326/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.8ms
# video 1/1 (327/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (328/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 5.9ms
# video 1/1 (329/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (330/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (331/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.9ms
# video 1/1 (332/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (333/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (334/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (335/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (336/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (337/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (338/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (339/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (340/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (341/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (342/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (343/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (344/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (345/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (346/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (347/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.1ms
# video 1/1 (348/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (349/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (350/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (351/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (352/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (353/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (354/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (355/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (356/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (357/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (358/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (359/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (360/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.6ms
# video 1/1 (361/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (362/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (363/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (364/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (365/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (366/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (367/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (368/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (369/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (370/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (371/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (372/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (373/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (374/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (375/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (376/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (377/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (378/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.3ms
# video 1/1 (379/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (380/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (381/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (382/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (383/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (384/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.5ms
# video 1/1 (385/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.8ms
# video 1/1 (386/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (387/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.8ms
# video 1/1 (388/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (389/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.8ms
# video 1/1 (390/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.5ms
# video 1/1 (391/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (392/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (393/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.8ms
# video 1/1 (394/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.4ms
# video 1/1 (395/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (396/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.2ms
# video 1/1 (397/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (398/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 5 balls, 6.3ms
# video 1/1 (399/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (400/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.8ms
# video 1/1 (401/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (402/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.2ms
# video 1/1 (403/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.3ms
# video 1/1 (404/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.6ms
# video 1/1 (405/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 5.9ms
# video 1/1 (406/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.3ms
# video 1/1 (407/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 5.9ms
# video 1/1 (408/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.4ms
# video 1/1 (409/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (410/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (411/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (412/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.8ms
# video 1/1 (413/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (414/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.2ms
# video 1/1 (415/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 5.9ms
# video 1/1 (416/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.2ms
# video 1/1 (417/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 7.3ms
# video 1/1 (418/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.3ms
# video 1/1 (419/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (420/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (421/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 5.9ms
# video 1/1 (422/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (423/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 5.9ms
# video 1/1 (424/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.8ms
# video 1/1 (425/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (426/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (427/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (428/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.2ms
# video 1/1 (429/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (430/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (431/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (432/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 5.9ms
# video 1/1 (433/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (434/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (435/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.1ms
# video 1/1 (436/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (437/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (438/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.2ms
# video 1/1 (439/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 5.9ms
# video 1/1 (440/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.3ms
# video 1/1 (441/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (442/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.3ms
# video 1/1 (443/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.3ms
# video 1/1 (444/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (445/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (446/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.0ms
# video 1/1 (447/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (448/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (449/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.4ms
# video 1/1 (450/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.3ms
# video 1/1 (451/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (452/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.3ms
# video 1/1 (453/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (454/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.2ms
# video 1/1 (455/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (456/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 4 balls, 6.1ms
# video 1/1 (457/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (458/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (459/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (460/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (461/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (462/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (463/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (464/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.0ms
# video 1/1 (465/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (466/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.9ms
# video 1/1 (467/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (468/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.5ms
# video 1/1 (469/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (470/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.5ms
# video 1/1 (471/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (472/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (473/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (474/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (475/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (476/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (477/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (478/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.1ms
# video 1/1 (479/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (480/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (481/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (482/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (483/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (484/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (485/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (486/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (487/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (488/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (489/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.0ms
# video 1/1 (490/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (491/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (492/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (493/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (494/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.2ms
# video 1/1 (495/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.0ms
# video 1/1 (496/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (497/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (498/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.0ms
# video 1/1 (499/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (500/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (501/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (502/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (503/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (504/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (505/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (506/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (507/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (508/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (509/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (510/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 9.9ms
# video 1/1 (511/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 9.7ms
# video 1/1 (512/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.9ms
# video 1/1 (513/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (514/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (515/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (516/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (517/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.0ms
# video 1/1 (518/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 8.1ms
# video 1/1 (519/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 9.6ms
# video 1/1 (520/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (521/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (522/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (523/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (524/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (525/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (526/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (527/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (528/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (529/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (530/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (531/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (532/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (533/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (534/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (535/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 6.2ms
# video 1/1 (536/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 3 balls, 7.0ms
# video 1/1 (537/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.6ms
# video 1/1 (538/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (539/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (540/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.3ms
# video 1/1 (541/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (542/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.4ms
# video 1/1 (543/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.8ms
# video 1/1 (544/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (545/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (546/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (547/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (548/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.4ms
# video 1/1 (549/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (550/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (551/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (552/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (553/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (554/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.8ms
# video 1/1 (555/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (556/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.1ms
# video 1/1 (557/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (558/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (559/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (560/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.4ms
# video 1/1 (561/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.1ms
# video 1/1 (562/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.1ms
# video 1/1 (563/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (564/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.1ms
# video 1/1 (565/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (566/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (567/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (568/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (569/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 7.4ms
# video 1/1 (570/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (571/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (572/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (573/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.4ms
# video 1/1 (574/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (575/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (576/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (577/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (578/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (579/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (580/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (581/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (582/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (583/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (584/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.3ms
# video 1/1 (585/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (586/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (587/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.6ms
# video 1/1 (588/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (589/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (590/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.3ms
# video 1/1 (591/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.5ms
# video 1/1 (592/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 (no detections), 6.2ms
# video 1/1 (593/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.3ms
# video 1/1 (594/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (595/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (596/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (597/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (598/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (599/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (600/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.2ms
# video 1/1 (601/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (602/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (603/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (604/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (605/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (606/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (607/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (608/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 2 balls, 6.3ms
# video 1/1 (609/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (610/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (611/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (612/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 7.0ms
# video 1/1 (613/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (614/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (615/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (616/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (617/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.2ms
# video 1/1 (618/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.1ms
# video 1/1 (619/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (620/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (621/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (622/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (623/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (624/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (625/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (626/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (627/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (628/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.3ms
# video 1/1 (629/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (630/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (631/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 6.7ms
# video 1/1 (632/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (633/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (634/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (635/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (636/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (637/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# video 1/1 (638/638) /kaggle/input/sampletennisvideo/sample1.mp4: 640x384 1 ball, 5.9ms
# Speed: 0.4ms pre-process, 6.4ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3
